# %%
import platform
print(f"platform.python_version(): {platform.python_version()}")

import os
import scipy
import numpy as np
from glob import glob
from tqdm import tqdm
import json

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow import keras
from keras import Sequential
from keras.utils import to_categorical
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, BatchNormalization, Activation

import matplotlib.pyplot as plt

# 在windows用gpu跑tensorflow 最多只支持到2.10.1並且conda沒有2.10.1 只能用pip
# numpy和scipy也要配合安裝下列版本
# pip install tensorflow==2.10.1
# pip install numpy==1.22.4
# pip install scipy==1.7.3
print(f"np.version.version: {np.version.version}")
print(f"scipy.__version__: {scipy.__version__}")
print(f"tf.__version__: {tf.__version__}")
# 確認GPU是否可用
gpus = tf.config.experimental.list_physical_devices('GPU')
print(f"tf.config.list_physical_devices('GPU'): {tf.config.list_physical_devices('GPU')}")
# Out:
# platform.python_version(): 3.9.13
# np.version.version: 1.22.4
# scipy.__version__: 1.7.3
# tf.__version__: 2.10.1
# tf.config.list_physical_devices('GPU'): [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# 取得訓練資料npy檔路徑放入 'npy_file_list'

# %%
npy_file_list = glob(f"..\\data\\mfcc\\*.npy")
print(f"type(npy_file_list): {type(npy_file_list)}")
print(f"len(npy_file_list): {len(npy_file_list)}")
# npy_file_list
# Out:
# type(npy_file_list): <class 'list'>
# len(npy_file_list): 39423

# %% [markdown]
# 將 'npy_file_list' 內所有npy檔轉成陣列並放入 'mfcc_list'

# %%
mfcc_list = []

for npy_file in tqdm(npy_file_list):
    mfcc = np.load(file=npy_file)
    mfcc_list.append(mfcc)

# 將list()轉換成np.array()
mfcc_list = np.array(mfcc_list)
print(f"type(mfcc_list): {type(mfcc_list)}")
print(f"mfcc_list.shape: {mfcc_list.shape}")

# 不要印出 ipynb會爆炸
# mfcc_list
# Out:
# 100%|██████████| 39423/39423 [00:06<00:00, 6340.19it/s]
# type(mfcc_list): <class 'numpy.ndarray'>
# mfcc_list.shape: (39423, 13, 44)

# %% [markdown]
# mfcc資料集標準化

# %%
scaler = StandardScaler()
# 因為標準器只能fit 2維的資料所以要將3維的mfcc資料集reshape成2維
# mfcc_data_nums: k
# mfcc_row: n
# mfcc_column: m
# (k, n, m) => (k * n, m)
scaler.fit(mfcc_list.reshape((mfcc_list.shape[0] * mfcc_list.shape[1], mfcc_list.shape[2])))

mfcc_list_scaled = []
for mfcc in mfcc_list:
    mfcc_list_scaled.append(scaler.transform(mfcc))

# 將list()轉換成np.array()
mfcc_list_scaled = np.array(mfcc_list_scaled)

print(f"type(mfcc_list_scaled): {type(mfcc_list_scaled)}")
print(f"mfcc_list_scaled.shape: {mfcc_list_scaled.shape}")

# 不要印出 ipynb會爆炸
# mfcc_scaled
# Out:
# type(mfcc_list_scaled): <class 'numpy.ndarray'>
# mfcc_list_scaled.shape: (39423, 13, 44)

# %% [markdown]
# 讀取 'npy_file_list' 中所有資料檔名的拼音標籤

# %%
label_pinyin_list = []

for npy_file in npy_file_list:
    label_pinyin = npy_file[npy_file.find("_") + 1:npy_file.find(".npy")]
    label_pinyin_list.append(label_pinyin)

# 將list()轉換成np.array()
label_pinyin_list = np.array(label_pinyin_list)

print(f"type(label_pinyin_list): {type(label_pinyin_list)}")
print(f"label_pinyin_list.shape: {label_pinyin_list.shape}")
# label_pinyin_list
# Out:
# type(label_pinyin_list): <class 'numpy.ndarray'>
# label_pinyin_list.shape: (39423,)

# %% [markdown]
# dictionary 標籤轉換器<br>key => pinyin<br>value => int<br>(0 <= int <= 1466)

# %%
sample_list = glob(f"..\\data\\samplePinyin\\Male\\*.wav")

label_dic: dict = {}
for i in range(len(sample_list)):
    label = sample_list[i][sample_list[i].find("_") + 1:sample_list[i].find(".wav")]
    label_dic[label] = i

print(f"type(label_dic): {type(label_dic)}")
print(f"len(label_dic): {len(label_dic)}")
# label_dic
# Out:
# type(label_dic): <class 'dict'>
# len(label_dic): 1467

# %% [markdown]
# 將 'label_pinyin_list' 裡的拼音標籤轉換成數字標籤放入 'label_int_list'

# %%
label_int_list = []
for label_pinyin in label_pinyin_list:
    label_int = label_dic[label_pinyin]
    label_int_list.append(label_int)

label_int_list = np.array(label_int_list)
print(f"label_int_list.shape => {label_int_list.shape}")
# label_int_list
# Out:
# label_int_list.shape => (39423,)

# %% [markdown]
# 定義CNN模型

# %%
def get_cnn_model(input_shape, num_classes, learning_rate=0.001, num_filters=32, dense_units=256):
    cnn_model = Sequential()

    # 第一層捲積層
    cnn_model.add(Conv2D(num_filters, kernel_size=(3, 3), padding='same', input_shape=input_shape))
    cnn_model.add(BatchNormalization())
    cnn_model.add(Activation('relu'))
    cnn_model.add(Conv2D(num_filters, kernel_size=(3, 3), padding='same'))
    cnn_model.add(BatchNormalization())
    cnn_model.add(Activation('relu'))
    cnn_model.add(MaxPooling2D(pool_size=(2, 2)))
    
    # 第二層捲積層
    cnn_model.add(Conv2D(num_filters * 2, kernel_size=(3, 3), padding='same'))
    cnn_model.add(BatchNormalization())
    cnn_model.add(Activation('relu'))
    cnn_model.add(Conv2D(num_filters * 2, kernel_size=(3, 3), padding='same'))
    cnn_model.add(BatchNormalization())
    cnn_model.add(Activation('relu'))
    cnn_model.add(MaxPooling2D(pool_size=(2, 2)))
    
    # 第三層捲積層
    cnn_model.add(Conv2D(num_filters * 4, kernel_size=(3, 3), padding='same'))
    cnn_model.add(BatchNormalization())
    cnn_model.add(Activation('relu'))
    cnn_model.add(Conv2D(num_filters * 4, kernel_size=(3, 3), padding='same'))
    cnn_model.add(BatchNormalization())
    cnn_model.add(Activation('relu'))
    cnn_model.add(MaxPooling2D(pool_size=(2, 2)))
    
    # 展平
    cnn_model.add(Flatten())
    
    # 第一層全連接層
    cnn_model.add(Dense(dense_units))
    cnn_model.add(BatchNormalization())
    cnn_model.add(Activation('relu'))
    
    # 第二層全連接層
    cnn_model.add(Dense(dense_units * 2))
    cnn_model.add(BatchNormalization())
    cnn_model.add(Activation('relu'))
    
    # 第三層全連接層(長度同為1467個label)
    cnn_model.add(Dense(num_classes))
    
    # 表示為機率
    cnn_model.add(Activation('softmax'))

    cnn_model.compile(
        loss=keras.losses.categorical_crossentropy,
        optimizer=keras.optimizers.Adam(learning_rate=learning_rate),
        metrics=['accuracy']
    )

    return cnn_model

# %% [markdown]
# 最佳超參數

# %%
best_params = json.load(open(f"..\\grid_search\\best_params.json", "r"))

learning_rate = best_params["learning_rate"]
num_filters = best_params["num_filters"]
dense_units = best_params["dense_unit"]
batch_size = best_params["batch_size"]
epochs = best_params["epochs"]

# %% [markdown]
# 基本參數

# %%
channel = 1
verbose = 2
num_classes = len(label_dic)
test_size = 0.2
mfcc_dim_1 = mfcc_list.shape[1]
mfcc_dim_2 = mfcc_list.shape[2]
print(f"mfcc_dim_1: {mfcc_dim_1}")
print(f"mfcc_dim_2: {mfcc_dim_2}")
# Out:
# mfcc_dim_1: 13
# mfcc_dim_2: 44

# %% [markdown]
# 資料分割

# %%
X = mfcc_list_scaled
y = label_int_list

# 將int label轉換成二進制one hot標籤
y_one_hot = to_categorical(y, num_classes=num_classes)

X_train, X_test, y_train, y_test = train_test_split(X, y_one_hot, test_size=test_size, random_state=42)

X_train = X_train.reshape(X_train.shape[0], mfcc_dim_1, mfcc_dim_2, channel)
X_test = X_test.reshape(X_test.shape[0], mfcc_dim_1, mfcc_dim_2, channel)

# %% [markdown]
# 訓練模型

# %%
model = get_cnn_model(input_shape=(mfcc_dim_1, mfcc_dim_2, channel), num_classes=num_classes, learning_rate=learning_rate, num_filters=num_filters, dense_units=dense_units)
model_train_info = model.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, verbose=verbose, validation_data=(X_test, y_test))
# Out:
# Epoch 1/300
# 247/247 - 7s - loss: 5.3567 - accuracy: 0.1235 - val_loss: 6.5272 - val_accuracy: 0.0297 - 7s/epoch - 29ms/step
# Epoch 2/300
# 247/247 - 5s - loss: 3.8143 - accuracy: 0.2598 - val_loss: 4.1518 - val_accuracy: 0.2148 - 5s/epoch - 20ms/step
# Epoch 3/300
# 247/247 - 5s - loss: 3.1432 - accuracy: 0.3488 - val_loss: 3.4427 - val_accuracy: 0.2898 - 5s/epoch - 20ms/step
# Epoch 4/300
# 247/247 - 5s - loss: 2.7042 - accuracy: 0.4158 - val_loss: 3.0155 - val_accuracy: 0.3736 - 5s/epoch - 20ms/step
# Epoch 5/300
# 247/247 - 5s - loss: 2.3574 - accuracy: 0.4794 - val_loss: 2.8355 - val_accuracy: 0.3923 - 5s/epoch - 20ms/step
# Epoch 6/300
# 247/247 - 5s - loss: 2.0599 - accuracy: 0.5336 - val_loss: 2.7070 - val_accuracy: 0.4100 - 5s/epoch - 20ms/step
# Epoch 7/300
# 247/247 - 5s - loss: 1.7785 - accuracy: 0.5870 - val_loss: 2.5663 - val_accuracy: 0.4370 - 5s/epoch - 20ms/step
# Epoch 8/300
# 247/247 - 5s - loss: 1.5029 - accuracy: 0.6463 - val_loss: 2.5304 - val_accuracy: 0.4383 - 5s/epoch - 20ms/step
# Epoch 9/300
# 247/247 - 5s - loss: 1.2332 - accuracy: 0.7136 - val_loss: 2.4452 - val_accuracy: 0.4601 - 5s/epoch - 20ms/step
# Epoch 10/300
# 247/247 - 5s - loss: 0.9593 - accuracy: 0.7873 - val_loss: 2.3705 - val_accuracy: 0.4711 - 5s/epoch - 20ms/step
# Epoch 11/300
# 247/247 - 5s - loss: 0.7289 - accuracy: 0.8427 - val_loss: 2.3954 - val_accuracy: 0.4654 - 5s/epoch - 20ms/step
# Epoch 12/300
# 247/247 - 5s - loss: 0.5399 - accuracy: 0.8889 - val_loss: 2.3507 - val_accuracy: 0.4755 - 5s/epoch - 20ms/step
# Epoch 13/300
# 247/247 - 5s - loss: 0.3968 - accuracy: 0.9270 - val_loss: 2.3660 - val_accuracy: 0.4752 - 5s/epoch - 20ms/step
# Epoch 14/300
# 247/247 - 5s - loss: 0.2909 - accuracy: 0.9523 - val_loss: 2.4005 - val_accuracy: 0.4731 - 5s/epoch - 20ms/step
# Epoch 15/300
# 247/247 - 5s - loss: 0.2097 - accuracy: 0.9686 - val_loss: 2.3914 - val_accuracy: 0.4723 - 5s/epoch - 20ms/step
# Epoch 16/300
# 247/247 - 5s - loss: 0.1527 - accuracy: 0.9788 - val_loss: 2.4318 - val_accuracy: 0.4742 - 5s/epoch - 20ms/step
# Epoch 17/300
# 247/247 - 5s - loss: 0.1117 - accuracy: 0.9866 - val_loss: 2.4234 - val_accuracy: 0.4744 - 5s/epoch - 20ms/step
# Epoch 18/300
# 247/247 - 5s - loss: 0.0822 - accuracy: 0.9907 - val_loss: 2.5464 - val_accuracy: 0.4713 - 5s/epoch - 20ms/step
# Epoch 19/300
# 247/247 - 5s - loss: 0.0667 - accuracy: 0.9931 - val_loss: 2.4664 - val_accuracy: 0.4845 - 5s/epoch - 20ms/step
# Epoch 20/300
# 247/247 - 5s - loss: 0.0542 - accuracy: 0.9940 - val_loss: 2.5568 - val_accuracy: 0.4691 - 5s/epoch - 20ms/step
# Epoch 21/300
# 247/247 - 5s - loss: 0.0861 - accuracy: 0.9877 - val_loss: 2.6407 - val_accuracy: 0.4573 - 5s/epoch - 20ms/step
# Epoch 22/300
# 247/247 - 5s - loss: 0.0811 - accuracy: 0.9890 - val_loss: 2.7068 - val_accuracy: 0.4495 - 5s/epoch - 20ms/step
# Epoch 23/300
# 247/247 - 5s - loss: 0.0754 - accuracy: 0.9891 - val_loss: 2.6817 - val_accuracy: 0.4516 - 5s/epoch - 20ms/step
# Epoch 24/300
# 247/247 - 5s - loss: 0.0592 - accuracy: 0.9914 - val_loss: 2.7291 - val_accuracy: 0.4635 - 5s/epoch - 20ms/step
# Epoch 25/300
# 247/247 - 5s - loss: 0.0647 - accuracy: 0.9892 - val_loss: 2.8050 - val_accuracy: 0.4435 - 5s/epoch - 20ms/step
# Epoch 26/300
# 247/247 - 5s - loss: 0.0598 - accuracy: 0.9903 - val_loss: 2.7784 - val_accuracy: 0.4534 - 5s/epoch - 20ms/step
# Epoch 27/300
# 247/247 - 5s - loss: 0.0417 - accuracy: 0.9937 - val_loss: 2.7293 - val_accuracy: 0.4709 - 5s/epoch - 20ms/step
# Epoch 28/300
# 247/247 - 5s - loss: 0.0262 - accuracy: 0.9966 - val_loss: 2.7316 - val_accuracy: 0.4777 - 5s/epoch - 20ms/step
# Epoch 29/300
# 247/247 - 5s - loss: 0.0401 - accuracy: 0.9932 - val_loss: 2.8870 - val_accuracy: 0.4507 - 5s/epoch - 20ms/step
# Epoch 30/300
# 247/247 - 5s - loss: 0.1442 - accuracy: 0.9690 - val_loss: 3.3773 - val_accuracy: 0.3660 - 5s/epoch - 20ms/step
# Epoch 31/300
# 247/247 - 5s - loss: 0.1049 - accuracy: 0.9809 - val_loss: 2.9152 - val_accuracy: 0.4550 - 5s/epoch - 20ms/step
# Epoch 32/300
# 247/247 - 5s - loss: 0.0202 - accuracy: 0.9978 - val_loss: 2.7604 - val_accuracy: 0.4833 - 5s/epoch - 20ms/step
# Epoch 33/300
# 247/247 - 5s - loss: 0.0106 - accuracy: 0.9983 - val_loss: 2.7765 - val_accuracy: 0.4871 - 5s/epoch - 20ms/step
# Epoch 34/300
# 247/247 - 5s - loss: 0.0218 - accuracy: 0.9955 - val_loss: 2.8618 - val_accuracy: 0.4602 - 5s/epoch - 20ms/step
# Epoch 35/300
# 247/247 - 5s - loss: 0.0333 - accuracy: 0.9933 - val_loss: 3.1016 - val_accuracy: 0.4505 - 5s/epoch - 20ms/step
# Epoch 36/300
# 247/247 - 5s - loss: 0.0830 - accuracy: 0.9809 - val_loss: 3.2544 - val_accuracy: 0.4052 - 5s/epoch - 20ms/step
# Epoch 37/300
# 247/247 - 5s - loss: 0.0735 - accuracy: 0.9843 - val_loss: 2.9653 - val_accuracy: 0.4531 - 5s/epoch - 20ms/step
# Epoch 38/300
# 247/247 - 5s - loss: 0.0387 - accuracy: 0.9924 - val_loss: 2.9790 - val_accuracy: 0.4583 - 5s/epoch - 20ms/step
# Epoch 39/300
# 247/247 - 5s - loss: 0.0174 - accuracy: 0.9975 - val_loss: 2.9250 - val_accuracy: 0.4784 - 5s/epoch - 20ms/step
# Epoch 40/300
# 247/247 - 5s - loss: 0.0145 - accuracy: 0.9973 - val_loss: 2.9711 - val_accuracy: 0.4734 - 5s/epoch - 20ms/step
# Epoch 41/300
# 247/247 - 5s - loss: 0.0113 - accuracy: 0.9980 - val_loss: 2.9506 - val_accuracy: 0.4772 - 5s/epoch - 20ms/step
# Epoch 42/300
# 247/247 - 5s - loss: 0.0225 - accuracy: 0.9960 - val_loss: 3.0899 - val_accuracy: 0.4604 - 5s/epoch - 20ms/step
# Epoch 43/300
# 247/247 - 5s - loss: 0.1128 - accuracy: 0.9710 - val_loss: 3.7388 - val_accuracy: 0.3678 - 5s/epoch - 20ms/step
# Epoch 44/300
# 247/247 - 5s - loss: 0.1049 - accuracy: 0.9744 - val_loss: 3.1311 - val_accuracy: 0.4520 - 5s/epoch - 20ms/step
# Epoch 45/300
# 247/247 - 5s - loss: 0.0202 - accuracy: 0.9965 - val_loss: 2.9638 - val_accuracy: 0.4761 - 5s/epoch - 20ms/step
# Epoch 46/300
# 247/247 - 5s - loss: 0.0084 - accuracy: 0.9985 - val_loss: 2.9312 - val_accuracy: 0.4895 - 5s/epoch - 20ms/step
# Epoch 47/300
# 247/247 - 5s - loss: 0.0052 - accuracy: 0.9991 - val_loss: 2.9911 - val_accuracy: 0.4902 - 5s/epoch - 20ms/step
# Epoch 48/300
# 247/247 - 5s - loss: 0.0063 - accuracy: 0.9984 - val_loss: 2.9758 - val_accuracy: 0.4886 - 5s/epoch - 20ms/step
# Epoch 49/300
# 247/247 - 5s - loss: 0.0108 - accuracy: 0.9974 - val_loss: 3.1672 - val_accuracy: 0.4557 - 5s/epoch - 20ms/step
# Epoch 50/300
# 247/247 - 5s - loss: 0.0621 - accuracy: 0.9835 - val_loss: 3.8891 - val_accuracy: 0.3649 - 5s/epoch - 20ms/step
# Epoch 51/300
# 247/247 - 5s - loss: 0.1510 - accuracy: 0.9586 - val_loss: 3.3484 - val_accuracy: 0.4341 - 5s/epoch - 20ms/step
# Epoch 52/300
# 247/247 - 5s - loss: 0.0270 - accuracy: 0.9946 - val_loss: 3.1440 - val_accuracy: 0.4742 - 5s/epoch - 20ms/step
# Epoch 53/300
# 247/247 - 5s - loss: 0.0098 - accuracy: 0.9983 - val_loss: 3.0429 - val_accuracy: 0.4900 - 5s/epoch - 21ms/step
# Epoch 54/300
# 247/247 - 5s - loss: 0.0040 - accuracy: 0.9992 - val_loss: 3.0067 - val_accuracy: 0.4951 - 5s/epoch - 20ms/step
# Epoch 55/300
# 247/247 - 5s - loss: 0.0030 - accuracy: 0.9993 - val_loss: 3.0067 - val_accuracy: 0.4978 - 5s/epoch - 22ms/step
# Epoch 56/300
# 247/247 - 5s - loss: 0.0027 - accuracy: 0.9992 - val_loss: 3.0789 - val_accuracy: 0.5012 - 5s/epoch - 21ms/step
# Epoch 57/300
# 247/247 - 5s - loss: 0.0046 - accuracy: 0.9988 - val_loss: 3.0379 - val_accuracy: 0.4913 - 5s/epoch - 20ms/step
# Epoch 58/300
# 247/247 - 5s - loss: 0.0399 - accuracy: 0.9895 - val_loss: 3.8904 - val_accuracy: 0.3874 - 5s/epoch - 20ms/step
# Epoch 59/300
# 247/247 - 5s - loss: 0.1871 - accuracy: 0.9470 - val_loss: 3.2698 - val_accuracy: 0.4394 - 5s/epoch - 20ms/step
# Epoch 60/300
# 247/247 - 5s - loss: 0.0277 - accuracy: 0.9944 - val_loss: 3.1618 - val_accuracy: 0.4736 - 5s/epoch - 20ms/step
# Epoch 61/300
# 247/247 - 5s - loss: 0.0105 - accuracy: 0.9978 - val_loss: 3.1234 - val_accuracy: 0.4843 - 5s/epoch - 21ms/step
# Epoch 62/300
# 247/247 - 5s - loss: 0.0055 - accuracy: 0.9990 - val_loss: 3.0785 - val_accuracy: 0.4932 - 5s/epoch - 20ms/step
# Epoch 63/300
# 247/247 - 5s - loss: 0.0032 - accuracy: 0.9992 - val_loss: 3.0901 - val_accuracy: 0.4984 - 5s/epoch - 20ms/step
# Epoch 64/300
# 247/247 - 5s - loss: 0.0031 - accuracy: 0.9992 - val_loss: 3.1132 - val_accuracy: 0.4960 - 5s/epoch - 20ms/step
# Epoch 65/300
# 247/247 - 5s - loss: 0.0028 - accuracy: 0.9992 - val_loss: 3.1019 - val_accuracy: 0.4982 - 5s/epoch - 20ms/step
# Epoch 66/300
# 247/247 - 5s - loss: 0.0024 - accuracy: 0.9993 - val_loss: 3.1038 - val_accuracy: 0.4993 - 5s/epoch - 21ms/step
# Epoch 67/300
# 247/247 - 5s - loss: 0.0022 - accuracy: 0.9993 - val_loss: 3.1183 - val_accuracy: 0.4983 - 5s/epoch - 21ms/step
# Epoch 68/300
# 247/247 - 5s - loss: 0.0022 - accuracy: 0.9993 - val_loss: 3.1200 - val_accuracy: 0.4989 - 5s/epoch - 21ms/step
# Epoch 69/300
# 247/247 - 5s - loss: 0.0023 - accuracy: 0.9993 - val_loss: 3.1438 - val_accuracy: 0.4990 - 5s/epoch - 22ms/step
# Epoch 70/300
# 247/247 - 5s - loss: 0.0027 - accuracy: 0.9992 - val_loss: 3.1791 - val_accuracy: 0.4979 - 5s/epoch - 21ms/step
# Epoch 71/300
# 247/247 - 5s - loss: 0.0026 - accuracy: 0.9992 - val_loss: 3.1367 - val_accuracy: 0.5002 - 5s/epoch - 20ms/step
# Epoch 72/300
# 247/247 - 5s - loss: 0.3029 - accuracy: 0.9060 - val_loss: 3.7343 - val_accuracy: 0.3871 - 5s/epoch - 20ms/step
# Epoch 73/300
# 247/247 - 5s - loss: 0.0829 - accuracy: 0.9781 - val_loss: 3.1023 - val_accuracy: 0.4744 - 5s/epoch - 22ms/step
# Epoch 74/300
# 247/247 - 5s - loss: 0.0137 - accuracy: 0.9982 - val_loss: 3.0527 - val_accuracy: 0.4869 - 5s/epoch - 20ms/step
# Epoch 75/300
# 247/247 - 5s - loss: 0.0045 - accuracy: 0.9991 - val_loss: 3.0804 - val_accuracy: 0.4937 - 5s/epoch - 20ms/step
# Epoch 76/300
# 247/247 - 5s - loss: 0.0030 - accuracy: 0.9993 - val_loss: 3.0946 - val_accuracy: 0.4936 - 5s/epoch - 20ms/step
# Epoch 77/300
# 247/247 - 5s - loss: 0.0026 - accuracy: 0.9993 - val_loss: 3.1063 - val_accuracy: 0.4942 - 5s/epoch - 22ms/step
# Epoch 78/300
# 247/247 - 5s - loss: 0.0023 - accuracy: 0.9992 - val_loss: 3.1127 - val_accuracy: 0.4970 - 5s/epoch - 21ms/step
# Epoch 79/300
# 247/247 - 5s - loss: 0.0022 - accuracy: 0.9992 - val_loss: 3.1170 - val_accuracy: 0.4974 - 5s/epoch - 21ms/step
# Epoch 80/300
# 247/247 - 5s - loss: 0.0020 - accuracy: 0.9994 - val_loss: 3.1360 - val_accuracy: 0.4940 - 5s/epoch - 20ms/step
# Epoch 81/300
# 247/247 - 5s - loss: 0.0021 - accuracy: 0.9993 - val_loss: 3.1236 - val_accuracy: 0.4984 - 5s/epoch - 20ms/step
# Epoch 82/300
# 247/247 - 5s - loss: 0.0019 - accuracy: 0.9993 - val_loss: 3.1742 - val_accuracy: 0.4992 - 5s/epoch - 20ms/step
# Epoch 83/300
# 247/247 - 5s - loss: 0.0020 - accuracy: 0.9993 - val_loss: 3.1617 - val_accuracy: 0.4969 - 5s/epoch - 20ms/step
# Epoch 84/300
# 247/247 - 5s - loss: 0.0020 - accuracy: 0.9992 - val_loss: 3.1690 - val_accuracy: 0.4969 - 5s/epoch - 20ms/step
# Epoch 85/300
# 247/247 - 5s - loss: 0.0022 - accuracy: 0.9992 - val_loss: 3.2167 - val_accuracy: 0.4973 - 5s/epoch - 20ms/step
# Epoch 86/300
# 247/247 - 5s - loss: 0.0025 - accuracy: 0.9993 - val_loss: 3.2366 - val_accuracy: 0.4955 - 5s/epoch - 21ms/step
# Epoch 87/300
# 247/247 - 5s - loss: 0.0023 - accuracy: 0.9992 - val_loss: 3.2413 - val_accuracy: 0.4989 - 5s/epoch - 21ms/step
# Epoch 88/300
# 247/247 - 5s - loss: 0.0022 - accuracy: 0.9994 - val_loss: 3.2008 - val_accuracy: 0.4983 - 5s/epoch - 20ms/step
# Epoch 89/300
# 247/247 - 5s - loss: 0.3307 - accuracy: 0.8976 - val_loss: 3.5295 - val_accuracy: 0.4227 - 5s/epoch - 20ms/step
# Epoch 90/300
# 247/247 - 5s - loss: 0.0544 - accuracy: 0.9869 - val_loss: 3.2701 - val_accuracy: 0.4772 - 5s/epoch - 20ms/step
# Epoch 91/300
# 247/247 - 5s - loss: 0.0093 - accuracy: 0.9987 - val_loss: 3.1463 - val_accuracy: 0.4890 - 5s/epoch - 20ms/step
# Epoch 92/300
# 247/247 - 5s - loss: 0.0044 - accuracy: 0.9991 - val_loss: 3.1419 - val_accuracy: 0.4992 - 5s/epoch - 20ms/step
# Epoch 93/300
# 247/247 - 5s - loss: 0.0028 - accuracy: 0.9993 - val_loss: 3.1523 - val_accuracy: 0.4990 - 5s/epoch - 20ms/step
# Epoch 94/300
# 247/247 - 5s - loss: 0.0024 - accuracy: 0.9994 - val_loss: 3.1656 - val_accuracy: 0.4987 - 5s/epoch - 20ms/step
# Epoch 95/300
# 247/247 - 5s - loss: 0.0022 - accuracy: 0.9993 - val_loss: 3.1648 - val_accuracy: 0.4990 - 5s/epoch - 20ms/step
# Epoch 96/300
# 247/247 - 5s - loss: 0.0020 - accuracy: 0.9993 - val_loss: 3.2054 - val_accuracy: 0.4992 - 5s/epoch - 20ms/step
# Epoch 97/300
# 247/247 - 5s - loss: 0.0019 - accuracy: 0.9993 - val_loss: 3.1988 - val_accuracy: 0.5001 - 5s/epoch - 20ms/step
# Epoch 98/300
# 247/247 - 5s - loss: 0.0018 - accuracy: 0.9992 - val_loss: 3.2029 - val_accuracy: 0.5004 - 5s/epoch - 20ms/step
# Epoch 99/300
# 247/247 - 5s - loss: 0.0018 - accuracy: 0.9992 - val_loss: 3.1966 - val_accuracy: 0.5003 - 5s/epoch - 20ms/step
# Epoch 100/300
# 247/247 - 5s - loss: 0.0017 - accuracy: 0.9994 - val_loss: 3.2302 - val_accuracy: 0.5006 - 5s/epoch - 20ms/step
# Epoch 101/300
# 247/247 - 5s - loss: 0.0018 - accuracy: 0.9994 - val_loss: 3.2307 - val_accuracy: 0.5001 - 5s/epoch - 20ms/step
# Epoch 102/300
# 247/247 - 5s - loss: 0.0017 - accuracy: 0.9993 - val_loss: 3.2824 - val_accuracy: 0.4982 - 5s/epoch - 20ms/step
# Epoch 103/300
# 247/247 - 5s - loss: 0.0018 - accuracy: 0.9993 - val_loss: 3.2090 - val_accuracy: 0.4980 - 5s/epoch - 20ms/step
# Epoch 104/300
# 247/247 - 5s - loss: 0.0018 - accuracy: 0.9993 - val_loss: 3.2300 - val_accuracy: 0.4982 - 5s/epoch - 20ms/step
# Epoch 105/300
# 247/247 - 5s - loss: 0.0018 - accuracy: 0.9994 - val_loss: 3.3273 - val_accuracy: 0.4963 - 5s/epoch - 20ms/step
# Epoch 106/300
# 247/247 - 5s - loss: 0.0021 - accuracy: 0.9993 - val_loss: 3.3973 - val_accuracy: 0.4978 - 5s/epoch - 20ms/step
# Epoch 107/300
# 247/247 - 5s - loss: 0.0022 - accuracy: 0.9991 - val_loss: 3.2999 - val_accuracy: 0.4919 - 5s/epoch - 20ms/step
# Epoch 108/300
# 247/247 - 5s - loss: 0.2345 - accuracy: 0.9302 - val_loss: 4.7085 - val_accuracy: 0.3560 - 5s/epoch - 20ms/step
# Epoch 109/300
# 247/247 - 5s - loss: 0.1767 - accuracy: 0.9438 - val_loss: 3.3330 - val_accuracy: 0.4495 - 5s/epoch - 20ms/step
# Epoch 110/300
# 247/247 - 5s - loss: 0.0196 - accuracy: 0.9962 - val_loss: 3.1837 - val_accuracy: 0.4834 - 5s/epoch - 20ms/step
# Epoch 111/300
# 247/247 - 5s - loss: 0.0055 - accuracy: 0.9991 - val_loss: 3.2279 - val_accuracy: 0.4931 - 5s/epoch - 20ms/step
# Epoch 112/300
# 247/247 - 5s - loss: 0.0029 - accuracy: 0.9994 - val_loss: 3.2184 - val_accuracy: 0.4946 - 5s/epoch - 20ms/step
# Epoch 113/300
# 247/247 - 5s - loss: 0.0024 - accuracy: 0.9992 - val_loss: 3.2192 - val_accuracy: 0.4968 - 5s/epoch - 20ms/step
# Epoch 114/300
# 247/247 - 5s - loss: 0.0021 - accuracy: 0.9992 - val_loss: 3.2219 - val_accuracy: 0.4989 - 5s/epoch - 20ms/step
# Epoch 115/300
# 247/247 - 5s - loss: 0.0019 - accuracy: 0.9993 - val_loss: 3.2407 - val_accuracy: 0.4973 - 5s/epoch - 20ms/step
# Epoch 116/300
# 247/247 - 5s - loss: 0.0019 - accuracy: 0.9992 - val_loss: 3.2704 - val_accuracy: 0.4989 - 5s/epoch - 20ms/step
# Epoch 117/300
# 247/247 - 5s - loss: 0.0017 - accuracy: 0.9993 - val_loss: 3.2609 - val_accuracy: 0.4983 - 5s/epoch - 20ms/step
# Epoch 118/300
# 247/247 - 5s - loss: 0.0016 - accuracy: 0.9993 - val_loss: 3.2670 - val_accuracy: 0.5004 - 5s/epoch - 20ms/step
# Epoch 119/300
# 247/247 - 5s - loss: 0.0016 - accuracy: 0.9993 - val_loss: 3.2732 - val_accuracy: 0.4992 - 5s/epoch - 20ms/step
# Epoch 120/300
# 247/247 - 5s - loss: 0.0016 - accuracy: 0.9993 - val_loss: 3.2944 - val_accuracy: 0.4984 - 5s/epoch - 20ms/step
# Epoch 121/300
# 247/247 - 5s - loss: 0.0015 - accuracy: 0.9993 - val_loss: 3.2954 - val_accuracy: 0.4978 - 5s/epoch - 20ms/step
# Epoch 122/300
# 247/247 - 5s - loss: 0.0015 - accuracy: 0.9994 - val_loss: 3.3309 - val_accuracy: 0.4980 - 5s/epoch - 20ms/step
# Epoch 123/300
# 247/247 - 5s - loss: 0.0014 - accuracy: 0.9993 - val_loss: 3.2951 - val_accuracy: 0.4985 - 5s/epoch - 20ms/step
# Epoch 124/300
# 247/247 - 5s - loss: 0.0015 - accuracy: 0.9993 - val_loss: 3.3804 - val_accuracy: 0.4965 - 5s/epoch - 20ms/step
# Epoch 125/300
# 247/247 - 5s - loss: 0.0014 - accuracy: 0.9993 - val_loss: 3.3517 - val_accuracy: 0.4959 - 5s/epoch - 20ms/step
# Epoch 126/300
# 247/247 - 5s - loss: 0.0016 - accuracy: 0.9993 - val_loss: 3.3497 - val_accuracy: 0.4980 - 5s/epoch - 20ms/step
# Epoch 127/300
# 247/247 - 5s - loss: 0.0019 - accuracy: 0.9993 - val_loss: 3.4481 - val_accuracy: 0.4997 - 5s/epoch - 20ms/step
# Epoch 128/300
# 247/247 - 5s - loss: 0.0017 - accuracy: 0.9993 - val_loss: 3.3421 - val_accuracy: 0.4925 - 5s/epoch - 20ms/step
# Epoch 129/300
# 247/247 - 5s - loss: 0.2696 - accuracy: 0.9173 - val_loss: 4.3898 - val_accuracy: 0.3701 - 5s/epoch - 20ms/step
# Epoch 130/300
# 247/247 - 5s - loss: 0.0841 - accuracy: 0.9757 - val_loss: 3.5345 - val_accuracy: 0.4561 - 5s/epoch - 20ms/step
# Epoch 131/300
# 247/247 - 5s - loss: 0.0114 - accuracy: 0.9981 - val_loss: 3.2960 - val_accuracy: 0.4880 - 5s/epoch - 20ms/step
# Epoch 132/300
# 247/247 - 5s - loss: 0.0038 - accuracy: 0.9992 - val_loss: 3.2879 - val_accuracy: 0.4898 - 5s/epoch - 20ms/step
# Epoch 133/300
# 247/247 - 5s - loss: 0.0025 - accuracy: 0.9992 - val_loss: 3.3056 - val_accuracy: 0.4938 - 5s/epoch - 20ms/step
# Epoch 134/300
# 247/247 - 5s - loss: 0.0021 - accuracy: 0.9993 - val_loss: 3.3348 - val_accuracy: 0.4923 - 5s/epoch - 20ms/step
# Epoch 135/300
# 247/247 - 5s - loss: 0.0020 - accuracy: 0.9993 - val_loss: 3.3269 - val_accuracy: 0.4907 - 5s/epoch - 20ms/step
# Epoch 136/300
# 247/247 - 5s - loss: 0.0026 - accuracy: 0.9990 - val_loss: 3.3584 - val_accuracy: 0.4932 - 5s/epoch - 20ms/step
# Epoch 137/300
# 247/247 - 5s - loss: 0.0153 - accuracy: 0.9964 - val_loss: 3.6139 - val_accuracy: 0.4698 - 5s/epoch - 20ms/step
# Epoch 138/300
# 247/247 - 5s - loss: 0.0512 - accuracy: 0.9855 - val_loss: 3.8703 - val_accuracy: 0.3923 - 5s/epoch - 20ms/step
# Epoch 139/300
# 247/247 - 5s - loss: 0.0705 - accuracy: 0.9791 - val_loss: 3.6912 - val_accuracy: 0.4394 - 5s/epoch - 20ms/step
# Epoch 140/300
# 247/247 - 5s - loss: 0.0272 - accuracy: 0.9932 - val_loss: 3.4340 - val_accuracy: 0.4771 - 5s/epoch - 20ms/step
# Epoch 141/300
# 247/247 - 5s - loss: 0.0121 - accuracy: 0.9967 - val_loss: 3.4427 - val_accuracy: 0.4809 - 5s/epoch - 20ms/step
# Epoch 142/300
# 247/247 - 5s - loss: 0.0064 - accuracy: 0.9983 - val_loss: 3.4837 - val_accuracy: 0.4827 - 5s/epoch - 20ms/step
# Epoch 143/300
# 247/247 - 5s - loss: 0.0047 - accuracy: 0.9986 - val_loss: 3.4035 - val_accuracy: 0.4928 - 5s/epoch - 20ms/step
# Epoch 144/300
# 247/247 - 5s - loss: 0.0041 - accuracy: 0.9986 - val_loss: 3.5083 - val_accuracy: 0.4815 - 5s/epoch - 20ms/step
# Epoch 145/300
# 247/247 - 5s - loss: 0.0127 - accuracy: 0.9972 - val_loss: 3.5161 - val_accuracy: 0.4723 - 5s/epoch - 20ms/step
# Epoch 146/300
# 247/247 - 5s - loss: 0.0139 - accuracy: 0.9962 - val_loss: 3.6716 - val_accuracy: 0.4696 - 5s/epoch - 20ms/step
# Epoch 147/300
# 247/247 - 5s - loss: 0.0471 - accuracy: 0.9866 - val_loss: 3.9511 - val_accuracy: 0.4033 - 5s/epoch - 20ms/step
# Epoch 148/300
# 247/247 - 5s - loss: 0.0502 - accuracy: 0.9857 - val_loss: 3.6940 - val_accuracy: 0.4596 - 5s/epoch - 20ms/step
# Epoch 149/300
# 247/247 - 5s - loss: 0.0214 - accuracy: 0.9944 - val_loss: 3.5587 - val_accuracy: 0.4705 - 5s/epoch - 20ms/step
# Epoch 150/300
# 247/247 - 5s - loss: 0.0109 - accuracy: 0.9973 - val_loss: 3.7054 - val_accuracy: 0.4677 - 5s/epoch - 20ms/step
# Epoch 151/300
# 247/247 - 5s - loss: 0.0061 - accuracy: 0.9983 - val_loss: 3.5553 - val_accuracy: 0.4840 - 5s/epoch - 20ms/step
# Epoch 152/300
# 247/247 - 5s - loss: 0.0027 - accuracy: 0.9992 - val_loss: 3.5260 - val_accuracy: 0.4895 - 5s/epoch - 20ms/step
# Epoch 153/300
# 247/247 - 5s - loss: 0.0038 - accuracy: 0.9989 - val_loss: 3.6345 - val_accuracy: 0.4845 - 5s/epoch - 20ms/step
# Epoch 154/300
# 247/247 - 5s - loss: 0.0070 - accuracy: 0.9979 - val_loss: 3.5744 - val_accuracy: 0.4746 - 5s/epoch - 20ms/step
# Epoch 155/300
# 247/247 - 5s - loss: 0.0254 - accuracy: 0.9934 - val_loss: 4.0683 - val_accuracy: 0.4133 - 5s/epoch - 20ms/step
# Epoch 156/300
# 247/247 - 5s - loss: 0.0617 - accuracy: 0.9818 - val_loss: 3.9549 - val_accuracy: 0.4287 - 5s/epoch - 20ms/step
# Epoch 157/300
# 247/247 - 5s - loss: 0.0310 - accuracy: 0.9914 - val_loss: 3.6487 - val_accuracy: 0.4658 - 5s/epoch - 20ms/step
# Epoch 158/300
# 247/247 - 5s - loss: 0.0090 - accuracy: 0.9978 - val_loss: 3.5560 - val_accuracy: 0.4782 - 5s/epoch - 20ms/step
# Epoch 159/300
# 247/247 - 5s - loss: 0.0100 - accuracy: 0.9972 - val_loss: 3.7938 - val_accuracy: 0.4595 - 5s/epoch - 20ms/step
# Epoch 160/300
# 247/247 - 5s - loss: 0.0057 - accuracy: 0.9986 - val_loss: 3.6865 - val_accuracy: 0.4793 - 5s/epoch - 20ms/step
# Epoch 161/300
# 247/247 - 5s - loss: 0.0031 - accuracy: 0.9990 - val_loss: 3.5996 - val_accuracy: 0.4856 - 5s/epoch - 20ms/step
# Epoch 162/300
# 247/247 - 5s - loss: 0.0026 - accuracy: 0.9991 - val_loss: 3.6242 - val_accuracy: 0.4895 - 5s/epoch - 20ms/step
# Epoch 163/300
# 247/247 - 5s - loss: 0.0111 - accuracy: 0.9975 - val_loss: 3.8399 - val_accuracy: 0.4571 - 5s/epoch - 20ms/step
# Epoch 164/300
# 247/247 - 5s - loss: 0.0411 - accuracy: 0.9903 - val_loss: 3.8929 - val_accuracy: 0.4482 - 5s/epoch - 20ms/step
# Epoch 165/300
# 247/247 - 5s - loss: 0.0322 - accuracy: 0.9908 - val_loss: 3.9531 - val_accuracy: 0.4455 - 5s/epoch - 20ms/step
# Epoch 166/300
# 247/247 - 5s - loss: 0.0164 - accuracy: 0.9954 - val_loss: 3.7797 - val_accuracy: 0.4667 - 5s/epoch - 20ms/step
# Epoch 167/300
# 247/247 - 5s - loss: 0.0100 - accuracy: 0.9970 - val_loss: 3.6392 - val_accuracy: 0.4728 - 5s/epoch - 20ms/step
# Epoch 168/300
# 247/247 - 5s - loss: 0.0057 - accuracy: 0.9983 - val_loss: 3.7488 - val_accuracy: 0.4761 - 5s/epoch - 20ms/step
# Epoch 169/300
# 247/247 - 5s - loss: 0.0049 - accuracy: 0.9982 - val_loss: 3.6358 - val_accuracy: 0.4760 - 5s/epoch - 20ms/step
# Epoch 170/300
# 247/247 - 5s - loss: 0.0127 - accuracy: 0.9966 - val_loss: 3.7960 - val_accuracy: 0.4640 - 5s/epoch - 20ms/step
# Epoch 171/300
# 247/247 - 5s - loss: 0.0209 - accuracy: 0.9943 - val_loss: 3.8728 - val_accuracy: 0.4450 - 5s/epoch - 20ms/step
# Epoch 172/300
# 247/247 - 5s - loss: 0.0342 - accuracy: 0.9908 - val_loss: 3.9511 - val_accuracy: 0.4341 - 5s/epoch - 20ms/step
# Epoch 173/300
# 247/247 - 5s - loss: 0.0267 - accuracy: 0.9928 - val_loss: 3.8684 - val_accuracy: 0.4585 - 5s/epoch - 20ms/step
# Epoch 174/300
# 247/247 - 5s - loss: 0.0132 - accuracy: 0.9961 - val_loss: 3.6994 - val_accuracy: 0.4667 - 5s/epoch - 20ms/step
# Epoch 175/300
# 247/247 - 5s - loss: 0.0055 - accuracy: 0.9983 - val_loss: 3.7363 - val_accuracy: 0.4855 - 5s/epoch - 20ms/step
# Epoch 176/300
# 247/247 - 5s - loss: 0.0029 - accuracy: 0.9990 - val_loss: 3.6622 - val_accuracy: 0.4917 - 5s/epoch - 20ms/step
# Epoch 177/300
# 247/247 - 5s - loss: 0.0016 - accuracy: 0.9992 - val_loss: 3.6953 - val_accuracy: 0.4931 - 5s/epoch - 20ms/step
# Epoch 178/300
# 247/247 - 5s - loss: 0.0012 - accuracy: 0.9994 - val_loss: 3.6850 - val_accuracy: 0.4925 - 5s/epoch - 20ms/step
# Epoch 179/300
# 247/247 - 5s - loss: 0.0012 - accuracy: 0.9993 - val_loss: 3.6899 - val_accuracy: 0.4949 - 5s/epoch - 20ms/step
# Epoch 180/300
# 247/247 - 5s - loss: 0.0011 - accuracy: 0.9992 - val_loss: 3.7101 - val_accuracy: 0.4965 - 5s/epoch - 20ms/step
# Epoch 181/300
# 247/247 - 5s - loss: 0.0011 - accuracy: 0.9992 - val_loss: 3.6816 - val_accuracy: 0.4947 - 5s/epoch - 20ms/step
# Epoch 182/300
# 247/247 - 5s - loss: 0.0011 - accuracy: 0.9993 - val_loss: 3.7043 - val_accuracy: 0.4969 - 5s/epoch - 20ms/step
# Epoch 183/300
# 247/247 - 5s - loss: 0.0011 - accuracy: 0.9993 - val_loss: 3.7290 - val_accuracy: 0.4955 - 5s/epoch - 20ms/step
# Epoch 184/300
# 247/247 - 5s - loss: 0.0011 - accuracy: 0.9992 - val_loss: 3.7197 - val_accuracy: 0.4980 - 5s/epoch - 20ms/step
# Epoch 185/300
# 247/247 - 5s - loss: 0.0011 - accuracy: 0.9994 - val_loss: 3.7349 - val_accuracy: 0.4969 - 5s/epoch - 20ms/step
# Epoch 186/300
# 247/247 - 5s - loss: 0.0011 - accuracy: 0.9993 - val_loss: 3.7326 - val_accuracy: 0.4946 - 5s/epoch - 20ms/step
# Epoch 187/300
# 247/247 - 5s - loss: 0.0012 - accuracy: 0.9993 - val_loss: 3.7845 - val_accuracy: 0.4930 - 5s/epoch - 20ms/step
# Epoch 188/300
# 247/247 - 5s - loss: 0.0013 - accuracy: 0.9991 - val_loss: 3.7409 - val_accuracy: 0.4963 - 5s/epoch - 20ms/step
# Epoch 189/300
# 247/247 - 5s - loss: 0.0012 - accuracy: 0.9993 - val_loss: 3.8231 - val_accuracy: 0.4950 - 5s/epoch - 20ms/step
# Epoch 190/300
# 247/247 - 5s - loss: 0.0013 - accuracy: 0.9994 - val_loss: 3.6587 - val_accuracy: 0.4944 - 5s/epoch - 20ms/step
# Epoch 191/300
# 247/247 - 5s - loss: 0.0917 - accuracy: 0.9724 - val_loss: 5.6325 - val_accuracy: 0.3207 - 5s/epoch - 20ms/step
# Epoch 192/300
# 247/247 - 5s - loss: 0.1019 - accuracy: 0.9683 - val_loss: 3.8644 - val_accuracy: 0.4478 - 5s/epoch - 20ms/step
# Epoch 193/300
# 247/247 - 5s - loss: 0.0104 - accuracy: 0.9972 - val_loss: 3.7389 - val_accuracy: 0.4799 - 5s/epoch - 20ms/step
# Epoch 194/300
# 247/247 - 5s - loss: 0.0029 - accuracy: 0.9991 - val_loss: 3.6992 - val_accuracy: 0.4865 - 5s/epoch - 20ms/step
# Epoch 195/300
# 247/247 - 5s - loss: 0.0017 - accuracy: 0.9993 - val_loss: 3.7003 - val_accuracy: 0.4866 - 5s/epoch - 20ms/step
# Epoch 196/300
# 247/247 - 5s - loss: 0.0015 - accuracy: 0.9993 - val_loss: 3.7097 - val_accuracy: 0.4916 - 5s/epoch - 20ms/step
# Epoch 197/300
# 247/247 - 5s - loss: 0.0014 - accuracy: 0.9992 - val_loss: 3.7070 - val_accuracy: 0.4927 - 5s/epoch - 20ms/step
# Epoch 198/300
# 247/247 - 5s - loss: 0.0013 - accuracy: 0.9993 - val_loss: 3.7276 - val_accuracy: 0.4945 - 5s/epoch - 20ms/step
# Epoch 199/300
# 247/247 - 5s - loss: 0.0012 - accuracy: 0.9992 - val_loss: 3.7220 - val_accuracy: 0.4930 - 5s/epoch - 20ms/step
# Epoch 200/300
# 247/247 - 5s - loss: 0.0012 - accuracy: 0.9993 - val_loss: 3.7323 - val_accuracy: 0.4946 - 5s/epoch - 20ms/step
# Epoch 201/300
# 247/247 - 5s - loss: 0.0012 - accuracy: 0.9993 - val_loss: 3.7318 - val_accuracy: 0.4960 - 5s/epoch - 20ms/step
# Epoch 202/300
# 247/247 - 5s - loss: 0.0011 - accuracy: 0.9992 - val_loss: 3.7474 - val_accuracy: 0.4958 - 5s/epoch - 20ms/step
# Epoch 203/300
# 247/247 - 5s - loss: 0.0011 - accuracy: 0.9993 - val_loss: 3.7381 - val_accuracy: 0.4956 - 5s/epoch - 20ms/step
# Epoch 204/300
# 247/247 - 5s - loss: 0.0011 - accuracy: 0.9993 - val_loss: 3.7517 - val_accuracy: 0.4959 - 5s/epoch - 20ms/step
# Epoch 205/300
# 247/247 - 5s - loss: 0.0010 - accuracy: 0.9994 - val_loss: 3.7825 - val_accuracy: 0.4947 - 5s/epoch - 20ms/step
# Epoch 206/300
# 247/247 - 5s - loss: 0.0011 - accuracy: 0.9994 - val_loss: 3.7469 - val_accuracy: 0.4922 - 5s/epoch - 20ms/step
# Epoch 207/300
# 247/247 - 5s - loss: 0.0011 - accuracy: 0.9993 - val_loss: 3.7672 - val_accuracy: 0.4926 - 5s/epoch - 20ms/step
# Epoch 208/300
# 247/247 - 5s - loss: 0.0011 - accuracy: 0.9992 - val_loss: 3.8263 - val_accuracy: 0.4978 - 5s/epoch - 20ms/step
# Epoch 209/300
# 247/247 - 5s - loss: 0.0011 - accuracy: 0.9993 - val_loss: 3.7731 - val_accuracy: 0.4949 - 5s/epoch - 20ms/step
# Epoch 210/300
# 247/247 - 5s - loss: 0.0011 - accuracy: 0.9992 - val_loss: 3.8184 - val_accuracy: 0.4963 - 5s/epoch - 20ms/step
# Epoch 211/300
# 247/247 - 5s - loss: 0.0011 - accuracy: 0.9994 - val_loss: 3.7986 - val_accuracy: 0.4945 - 5s/epoch - 20ms/step
# Epoch 212/300
# 247/247 - 5s - loss: 0.0011 - accuracy: 0.9993 - val_loss: 3.9048 - val_accuracy: 0.4958 - 5s/epoch - 20ms/step
# Epoch 213/300
# 247/247 - 5s - loss: 0.0011 - accuracy: 0.9992 - val_loss: 3.8814 - val_accuracy: 0.4959 - 5s/epoch - 20ms/step
# Epoch 214/300
# 247/247 - 5s - loss: 0.0012 - accuracy: 0.9992 - val_loss: 3.8308 - val_accuracy: 0.4866 - 5s/epoch - 20ms/step
# Epoch 215/300
# 247/247 - 5s - loss: 0.0012 - accuracy: 0.9993 - val_loss: 3.8403 - val_accuracy: 0.4890 - 5s/epoch - 20ms/step
# Epoch 216/300
# 247/247 - 5s - loss: 0.1895 - accuracy: 0.9407 - val_loss: 4.3642 - val_accuracy: 0.4162 - 5s/epoch - 20ms/step
# Epoch 217/300
# 247/247 - 5s - loss: 0.0324 - accuracy: 0.9906 - val_loss: 3.8218 - val_accuracy: 0.4736 - 5s/epoch - 20ms/step
# Epoch 218/300
# 247/247 - 5s - loss: 0.0053 - accuracy: 0.9988 - val_loss: 3.7858 - val_accuracy: 0.4765 - 5s/epoch - 20ms/step
# Epoch 219/300
# 247/247 - 5s - loss: 0.0028 - accuracy: 0.9991 - val_loss: 3.7169 - val_accuracy: 0.4802 - 5s/epoch - 20ms/step
# Epoch 220/300
# 247/247 - 5s - loss: 0.0038 - accuracy: 0.9989 - val_loss: 3.8028 - val_accuracy: 0.4812 - 5s/epoch - 20ms/step
# Epoch 221/300
# 247/247 - 5s - loss: 0.0024 - accuracy: 0.9991 - val_loss: 3.7823 - val_accuracy: 0.4881 - 5s/epoch - 20ms/step
# Epoch 222/300
# 247/247 - 5s - loss: 0.0014 - accuracy: 0.9993 - val_loss: 3.7860 - val_accuracy: 0.4864 - 5s/epoch - 20ms/step
# Epoch 223/300
# 247/247 - 5s - loss: 0.0013 - accuracy: 0.9992 - val_loss: 3.7616 - val_accuracy: 0.4864 - 5s/epoch - 20ms/step
# Epoch 224/300
# 247/247 - 5s - loss: 0.0012 - accuracy: 0.9992 - val_loss: 3.7717 - val_accuracy: 0.4869 - 5s/epoch - 20ms/step
# Epoch 225/300
# 247/247 - 5s - loss: 0.0011 - accuracy: 0.9993 - val_loss: 3.7777 - val_accuracy: 0.4864 - 5s/epoch - 20ms/step
# Epoch 226/300
# 247/247 - 5s - loss: 0.0011 - accuracy: 0.9993 - val_loss: 3.8089 - val_accuracy: 0.4884 - 5s/epoch - 20ms/step
# Epoch 227/300
# 247/247 - 5s - loss: 0.0011 - accuracy: 0.9993 - val_loss: 3.7972 - val_accuracy: 0.4890 - 5s/epoch - 20ms/step
# Epoch 228/300
# 247/247 - 5s - loss: 0.0011 - accuracy: 0.9993 - val_loss: 3.8066 - val_accuracy: 0.4883 - 5s/epoch - 20ms/step
# Epoch 229/300
# 247/247 - 5s - loss: 0.0010 - accuracy: 0.9992 - val_loss: 3.7918 - val_accuracy: 0.4893 - 5s/epoch - 20ms/step
# Epoch 230/300
# 247/247 - 5s - loss: 0.0010 - accuracy: 0.9994 - val_loss: 3.8370 - val_accuracy: 0.4899 - 5s/epoch - 20ms/step
# Epoch 231/300
# 247/247 - 5s - loss: 9.8960e-04 - accuracy: 0.9994 - val_loss: 3.8332 - val_accuracy: 0.4923 - 5s/epoch - 20ms/step
# Epoch 232/300
# 247/247 - 5s - loss: 0.0010 - accuracy: 0.9993 - val_loss: 3.8161 - val_accuracy: 0.4927 - 5s/epoch - 20ms/step
# Epoch 233/300
# 247/247 - 5s - loss: 9.7865e-04 - accuracy: 0.9992 - val_loss: 3.8347 - val_accuracy: 0.4902 - 5s/epoch - 20ms/step
# Epoch 234/300
# 247/247 - 5s - loss: 9.7309e-04 - accuracy: 0.9994 - val_loss: 3.8386 - val_accuracy: 0.4922 - 5s/epoch - 20ms/step
# Epoch 235/300
# 247/247 - 5s - loss: 9.8495e-04 - accuracy: 0.9991 - val_loss: 3.8215 - val_accuracy: 0.4944 - 5s/epoch - 20ms/step
# Epoch 236/300
# 247/247 - 5s - loss: 9.8955e-04 - accuracy: 0.9993 - val_loss: 3.9291 - val_accuracy: 0.4928 - 5s/epoch - 20ms/step
# Epoch 237/300
# 247/247 - 5s - loss: 9.7384e-04 - accuracy: 0.9994 - val_loss: 3.8643 - val_accuracy: 0.4921 - 5s/epoch - 20ms/step
# Epoch 238/300
# 247/247 - 5s - loss: 0.0010 - accuracy: 0.9993 - val_loss: 3.8645 - val_accuracy: 0.4933 - 5s/epoch - 20ms/step
# Epoch 239/300
# 247/247 - 5s - loss: 9.6465e-04 - accuracy: 0.9993 - val_loss: 3.7994 - val_accuracy: 0.4964 - 5s/epoch - 20ms/step
# Epoch 240/300
# 247/247 - 5s - loss: 0.0010 - accuracy: 0.9994 - val_loss: 3.9562 - val_accuracy: 0.4900 - 5s/epoch - 20ms/step
# Epoch 241/300
# 247/247 - 5s - loss: 0.0012 - accuracy: 0.9993 - val_loss: 4.0705 - val_accuracy: 0.4782 - 5s/epoch - 20ms/step
# Epoch 242/300
# 247/247 - 5s - loss: 0.1984 - accuracy: 0.9394 - val_loss: 4.0306 - val_accuracy: 0.4453 - 5s/epoch - 20ms/step
# Epoch 243/300
# 247/247 - 5s - loss: 0.0285 - accuracy: 0.9925 - val_loss: 3.7631 - val_accuracy: 0.4662 - 5s/epoch - 20ms/step
# Epoch 244/300
# 247/247 - 5s - loss: 0.0049 - accuracy: 0.9986 - val_loss: 3.8858 - val_accuracy: 0.4828 - 5s/epoch - 20ms/step
# Epoch 245/300
# 247/247 - 5s - loss: 0.0019 - accuracy: 0.9993 - val_loss: 3.8534 - val_accuracy: 0.4879 - 5s/epoch - 20ms/step
# Epoch 246/300
# 247/247 - 5s - loss: 0.0015 - accuracy: 0.9994 - val_loss: 3.8733 - val_accuracy: 0.4881 - 5s/epoch - 20ms/step
# Epoch 247/300
# 247/247 - 5s - loss: 0.0014 - accuracy: 0.9993 - val_loss: 3.8759 - val_accuracy: 0.4904 - 5s/epoch - 20ms/step
# Epoch 248/300
# 247/247 - 5s - loss: 0.0013 - accuracy: 0.9993 - val_loss: 3.8784 - val_accuracy: 0.4890 - 5s/epoch - 20ms/step
# Epoch 249/300
# 247/247 - 5s - loss: 0.0012 - accuracy: 0.9993 - val_loss: 3.8853 - val_accuracy: 0.4919 - 5s/epoch - 20ms/step
# Epoch 250/300
# 247/247 - 5s - loss: 0.0011 - accuracy: 0.9993 - val_loss: 3.9021 - val_accuracy: 0.4921 - 5s/epoch - 20ms/step
# Epoch 251/300
# 247/247 - 5s - loss: 0.0011 - accuracy: 0.9993 - val_loss: 3.8980 - val_accuracy: 0.4913 - 5s/epoch - 20ms/step
# Epoch 252/300
# 247/247 - 5s - loss: 0.0011 - accuracy: 0.9993 - val_loss: 3.8946 - val_accuracy: 0.4927 - 5s/epoch - 20ms/step
# Epoch 253/300
# 247/247 - 5s - loss: 0.0011 - accuracy: 0.9993 - val_loss: 3.8899 - val_accuracy: 0.4922 - 5s/epoch - 20ms/step
# Epoch 254/300
# 247/247 - 5s - loss: 0.0010 - accuracy: 0.9993 - val_loss: 3.9357 - val_accuracy: 0.4940 - 5s/epoch - 20ms/step
# Epoch 255/300
# 247/247 - 5s - loss: 9.9731e-04 - accuracy: 0.9993 - val_loss: 3.9234 - val_accuracy: 0.4938 - 5s/epoch - 20ms/step
# Epoch 256/300
# 247/247 - 5s - loss: 9.9550e-04 - accuracy: 0.9994 - val_loss: 3.9490 - val_accuracy: 0.4951 - 5s/epoch - 20ms/step
# Epoch 257/300
# 247/247 - 5s - loss: 9.6913e-04 - accuracy: 0.9993 - val_loss: 3.9130 - val_accuracy: 0.4942 - 5s/epoch - 20ms/step
# Epoch 258/300
# 247/247 - 5s - loss: 9.5505e-04 - accuracy: 0.9993 - val_loss: 3.9329 - val_accuracy: 0.4928 - 5s/epoch - 20ms/step
# Epoch 259/300
# 247/247 - 5s - loss: 9.5522e-04 - accuracy: 0.9993 - val_loss: 3.9583 - val_accuracy: 0.4973 - 5s/epoch - 20ms/step
# Epoch 260/300
# 247/247 - 5s - loss: 9.7788e-04 - accuracy: 0.9992 - val_loss: 3.9757 - val_accuracy: 0.4945 - 5s/epoch - 20ms/step
# Epoch 261/300
# 247/247 - 5s - loss: 9.4228e-04 - accuracy: 0.9991 - val_loss: 3.9398 - val_accuracy: 0.4937 - 5s/epoch - 20ms/step
# Epoch 262/300
# 247/247 - 5s - loss: 9.1741e-04 - accuracy: 0.9994 - val_loss: 3.9520 - val_accuracy: 0.4946 - 5s/epoch - 20ms/step
# Epoch 263/300
# 247/247 - 5s - loss: 9.3851e-04 - accuracy: 0.9993 - val_loss: 3.9701 - val_accuracy: 0.4961 - 5s/epoch - 20ms/step
# Epoch 264/300
# 247/247 - 5s - loss: 9.5775e-04 - accuracy: 0.9993 - val_loss: 4.0706 - val_accuracy: 0.4944 - 5s/epoch - 20ms/step
# Epoch 265/300
# 247/247 - 5s - loss: 0.0010 - accuracy: 0.9993 - val_loss: 4.0899 - val_accuracy: 0.4888 - 5s/epoch - 20ms/step
# Epoch 266/300
# 247/247 - 5s - loss: 0.0012 - accuracy: 0.9993 - val_loss: 4.0669 - val_accuracy: 0.4838 - 5s/epoch - 20ms/step
# Epoch 267/300
# 247/247 - 5s - loss: 0.1506 - accuracy: 0.9533 - val_loss: 5.2501 - val_accuracy: 0.4020 - 5s/epoch - 20ms/step
# Epoch 268/300
# 247/247 - 5s - loss: 0.0434 - accuracy: 0.9868 - val_loss: 4.2936 - val_accuracy: 0.4536 - 5s/epoch - 20ms/step
# Epoch 269/300
# 247/247 - 5s - loss: 0.0061 - accuracy: 0.9987 - val_loss: 3.9072 - val_accuracy: 0.4805 - 5s/epoch - 20ms/step
# Epoch 270/300
# 247/247 - 5s - loss: 0.0021 - accuracy: 0.9993 - val_loss: 3.9145 - val_accuracy: 0.4841 - 5s/epoch - 20ms/step
# Epoch 271/300
# 247/247 - 5s - loss: 0.0015 - accuracy: 0.9992 - val_loss: 3.9057 - val_accuracy: 0.4880 - 5s/epoch - 20ms/step
# Epoch 272/300
# 247/247 - 5s - loss: 0.0014 - accuracy: 0.9992 - val_loss: 3.9164 - val_accuracy: 0.4875 - 5s/epoch - 20ms/step
# Epoch 273/300
# 247/247 - 5s - loss: 0.0013 - accuracy: 0.9993 - val_loss: 3.9358 - val_accuracy: 0.4883 - 5s/epoch - 20ms/step
# Epoch 274/300
# 247/247 - 5s - loss: 0.0012 - accuracy: 0.9993 - val_loss: 3.9129 - val_accuracy: 0.4895 - 5s/epoch - 20ms/step
# Epoch 275/300
# 247/247 - 5s - loss: 0.0011 - accuracy: 0.9992 - val_loss: 3.9431 - val_accuracy: 0.4897 - 5s/epoch - 20ms/step
# Epoch 276/300
# 247/247 - 5s - loss: 0.0011 - accuracy: 0.9993 - val_loss: 3.9407 - val_accuracy: 0.4886 - 5s/epoch - 20ms/step
# Epoch 277/300
# 247/247 - 5s - loss: 0.0010 - accuracy: 0.9994 - val_loss: 3.9338 - val_accuracy: 0.4912 - 5s/epoch - 20ms/step
# Epoch 278/300
# 247/247 - 5s - loss: 0.0010 - accuracy: 0.9993 - val_loss: 3.9476 - val_accuracy: 0.4919 - 5s/epoch - 20ms/step
# Epoch 279/300
# 247/247 - 5s - loss: 9.8923e-04 - accuracy: 0.9993 - val_loss: 3.9602 - val_accuracy: 0.4908 - 5s/epoch - 20ms/step
# Epoch 280/300
# 247/247 - 5s - loss: 9.6595e-04 - accuracy: 0.9992 - val_loss: 3.9535 - val_accuracy: 0.4923 - 5s/epoch - 20ms/step
# Epoch 281/300
# 247/247 - 5s - loss: 9.6036e-04 - accuracy: 0.9994 - val_loss: 3.9853 - val_accuracy: 0.4912 - 5s/epoch - 20ms/step
# Epoch 282/300
# 247/247 - 5s - loss: 9.2784e-04 - accuracy: 0.9994 - val_loss: 3.9874 - val_accuracy: 0.4927 - 5s/epoch - 20ms/step
# Epoch 283/300
# 247/247 - 5s - loss: 9.3288e-04 - accuracy: 0.9992 - val_loss: 3.9945 - val_accuracy: 0.4928 - 5s/epoch - 20ms/step
# Epoch 284/300
# 247/247 - 5s - loss: 9.1804e-04 - accuracy: 0.9993 - val_loss: 3.9763 - val_accuracy: 0.4936 - 5s/epoch - 20ms/step
# Epoch 285/300
# 247/247 - 5s - loss: 9.1832e-04 - accuracy: 0.9994 - val_loss: 4.0252 - val_accuracy: 0.4936 - 5s/epoch - 20ms/step
# Epoch 286/300
# 247/247 - 5s - loss: 9.1170e-04 - accuracy: 0.9993 - val_loss: 4.0167 - val_accuracy: 0.4942 - 5s/epoch - 20ms/step
# Epoch 287/300
# 247/247 - 5s - loss: 9.3073e-04 - accuracy: 0.9993 - val_loss: 4.0064 - val_accuracy: 0.4933 - 5s/epoch - 20ms/step
# Epoch 288/300
# 247/247 - 5s - loss: 0.1726 - accuracy: 0.9460 - val_loss: 4.6415 - val_accuracy: 0.4231 - 5s/epoch - 20ms/step
# Epoch 289/300
# 247/247 - 5s - loss: 0.0278 - accuracy: 0.9922 - val_loss: 3.9318 - val_accuracy: 0.4696 - 5s/epoch - 20ms/step
# Epoch 290/300
# 247/247 - 5s - loss: 0.0051 - accuracy: 0.9988 - val_loss: 3.9180 - val_accuracy: 0.4793 - 5s/epoch - 20ms/step
# Epoch 291/300
# 247/247 - 5s - loss: 0.0030 - accuracy: 0.9990 - val_loss: 3.9088 - val_accuracy: 0.4841 - 5s/epoch - 20ms/step
# Epoch 292/300
# 247/247 - 5s - loss: 0.0018 - accuracy: 0.9992 - val_loss: 3.9050 - val_accuracy: 0.4823 - 5s/epoch - 20ms/step
# Epoch 293/300
# 247/247 - 5s - loss: 0.0013 - accuracy: 0.9993 - val_loss: 3.9144 - val_accuracy: 0.4842 - 5s/epoch - 20ms/step
# Epoch 294/300
# 247/247 - 5s - loss: 0.0012 - accuracy: 0.9992 - val_loss: 3.9280 - val_accuracy: 0.4850 - 5s/epoch - 20ms/step
# Epoch 295/300
# 247/247 - 5s - loss: 0.0011 - accuracy: 0.9992 - val_loss: 3.9307 - val_accuracy: 0.4860 - 5s/epoch - 20ms/step
# Epoch 296/300
# 247/247 - 5s - loss: 0.0011 - accuracy: 0.9993 - val_loss: 3.9290 - val_accuracy: 0.4873 - 5s/epoch - 20ms/step
# Epoch 297/300
# 247/247 - 5s - loss: 0.0010 - accuracy: 0.9993 - val_loss: 3.9340 - val_accuracy: 0.4880 - 5s/epoch - 20ms/step
# Epoch 298/300
# 247/247 - 5s - loss: 0.0010 - accuracy: 0.9993 - val_loss: 3.9453 - val_accuracy: 0.4881 - 5s/epoch - 20ms/step
# Epoch 299/300
# 247/247 - 5s - loss: 0.0010 - accuracy: 0.9993 - val_loss: 3.9538 - val_accuracy: 0.4888 - 5s/epoch - 20ms/step
# Epoch 300/300
# 247/247 - 5s - loss: 9.7218e-04 - accuracy: 0.9993 - val_loss: 3.9586 - val_accuracy: 0.4885 - 5s/epoch - 20ms/step

# %%
accuracies = model_train_info.history['accuracy']
val_accuracies = model_train_info.history['val_accuracy']

plt.plot(list(range(epochs)), accuracies, label = 'accuracy')
plt.plot(list(range(epochs)), val_accuracies, label = 'val_accuracy')
plt.legend()
plt.grid()
plt.xticks(ticks = list(range(1, epochs + 1))) 
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.xticks(ticks=list(range(0, epochs + 1, 50)))
plt.show()

# %% [markdown]
# 準確度

# %%
print(f"資料: {mfcc_list_scaled.shape}")
print(f"最高準確率: {max(val_accuracies)}")
# Out:
# 資料: (39423, 13, 44)
# 最高準確率: 0.5012048482894897

# %%
model.save(f".\\cnn_model.h5")
