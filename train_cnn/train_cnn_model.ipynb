# %%
import platform
print(f"platform.python_version(): {platform.python_version()}")

import os
import scipy
import numpy as np
from glob import glob
from tqdm import tqdm
import json

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow import keras
from keras import Sequential
from keras.utils import to_categorical
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, BatchNormalization, Activation

import matplotlib.pyplot as plt

# 在windows用gpu跑tensorflow 最多只支持到2.10.1並且conda沒有2.10.1 只能用pip
# numpy和scipy也要配合安裝下列版本
# pip install tensorflow==2.10.1
# pip install numpy==1.22.4
# pip install scipy==1.7.3
print(f"np.version.version: {np.version.version}")
print(f"scipy.__version__: {scipy.__version__}")
print(f"tf.__version__: {tf.__version__}")
# 確認GPU是否可用
gpus = tf.config.experimental.list_physical_devices('GPU')
print(f"tf.config.list_physical_devices('GPU'): {tf.config.list_physical_devices('GPU')}")
# Out:
# platform.python_version(): 3.9.13
# np.version.version: 1.22.4
# scipy.__version__: 1.7.3
# tf.__version__: 2.10.1
# tf.config.list_physical_devices('GPU'): [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# 取得訓練資料npy檔路徑放入 'npy_file_list'

# %%
npy_file_list = glob(f"{os.getcwd()}\\mfcc\\*.npy")
print(f"type(npy_file_list): {type(npy_file_list)}")
print(f"len(npy_file_list): {len(npy_file_list)}")
# npy_file_list
# Out:
# type(npy_file_list): <class 'list'>
# len(npy_file_list): 39423

# %% [markdown]
# 將 'npy_file_list' 內所有npy檔轉成陣列並放入 'mfcc_list'

# %%
mfcc_list = []

for npy_file in tqdm(npy_file_list):
    mfcc = np.load(file=npy_file)
    mfcc_list.append(mfcc)

# 將list()轉換成np.array()
mfcc_list = np.array(mfcc_list)
print(f"type(mfcc_list): {type(mfcc_list)}")
print(f"mfcc_list.shape: {mfcc_list.shape}")

# 不要印出 ipynb會爆炸
# mfcc_list
# Out:
# 100%|██████████| 39423/39423 [02:04<00:00, 316.08it/s]
# type(mfcc_list): <class 'numpy.ndarray'>
# mfcc_list.shape: (39423, 13, 44)

# %% [markdown]
# mfcc資料集標準化

# %%
scaler = StandardScaler()
# 因為標準器只能fit 2維的資料所以要將3維的mfcc資料集reshape成2維
# mfcc_data_nums: k
# mfcc_row: n
# mfcc_column: m
# (k, n, m) => (k * n, m)
scaler.fit(mfcc_list.reshape((mfcc_list.shape[0] * mfcc_list.shape[1], mfcc_list.shape[2])))

mfcc_list_scaled = []
for mfcc in mfcc_list:
    mfcc_list_scaled.append(scaler.transform(mfcc))

# 將list()轉換成np.array()
mfcc_list_scaled = np.array(mfcc_list_scaled)

print(f"type(mfcc_list_scaled): {type(mfcc_list_scaled)}")
print(f"mfcc_list_scaled.shape: {mfcc_list_scaled.shape}")

# 不要印出 ipynb會爆炸
# mfcc_scaled
# Out:
# type(mfcc_list_scaled): <class 'numpy.ndarray'>
# mfcc_list_scaled.shape: (39423, 13, 44)

# %% [markdown]
# 讀取 'npy_file_list' 中所有資料檔名的拼音標籤

# %%
label_pinyin_list = []

for npy_file in npy_file_list:
    label_pinyin = npy_file[npy_file.find("_") + 1:npy_file.find(".npy")]
    label_pinyin_list.append(label_pinyin)

# 將list()轉換成np.array()
label_pinyin_list = np.array(label_pinyin_list)

print(f"type(label_pinyin_list): {type(label_pinyin_list)}")
print(f"label_pinyin_list.shape: {label_pinyin_list.shape}")
# label_pinyin_list
# Out:
# type(label_pinyin_list): <class 'numpy.ndarray'>
# label_pinyin_list.shape: (39423,)

# %% [markdown]
# dictionary 標籤轉換器<br>key => pinyin<br>value => int<br>(0 <= int <= 1466)

# %%
sample_list = glob(f"{os.getcwd()}\\samplePinyin\\Male\\*.wav")

label_dic: dict = {}
for i in range(len(sample_list)):
    label = sample_list[i][sample_list[i].find("_") + 1:sample_list[i].find(".wav")]
    label_dic[label] = i

print(f"type(label_dic): {type(label_dic)}")
print(f"len(label_dic): {len(label_dic)}")
# label_dic
# Out:
# type(label_dic): <class 'dict'>
# len(label_dic): 1467

# %% [markdown]
# 將 'label_pinyin_list' 裡的拼音標籤轉換成數字標籤放入 'label_int_list'

# %%
label_int_list = []
for label_pinyin in label_pinyin_list:
    label_int = label_dic[label_pinyin]
    label_int_list.append(label_int)

label_int_list = np.array(label_int_list)
print(f"label_int_list.shape => {label_int_list.shape}")
# label_int_list
# Out:
# label_int_list.shape => (39423,)

# %% [markdown]
# 定義CNN模型

# %%
def get_cnn_model(input_shape, num_classes, learning_rate=0.001, num_filters=32, dense_units=256):
    cnn_model = Sequential()

    # 第一層捲積層
    cnn_model.add(Conv2D(num_filters, kernel_size=(3, 3), padding='same', input_shape=input_shape))
    cnn_model.add(BatchNormalization())
    cnn_model.add(Activation('relu'))
    cnn_model.add(Conv2D(num_filters, kernel_size=(3, 3), padding='same'))
    cnn_model.add(BatchNormalization())
    cnn_model.add(Activation('relu'))
    cnn_model.add(MaxPooling2D(pool_size=(2, 2)))
    
    # 第二層捲積層
    cnn_model.add(Conv2D(num_filters * 2, kernel_size=(3, 3), padding='same'))
    cnn_model.add(BatchNormalization())
    cnn_model.add(Activation('relu'))
    cnn_model.add(Conv2D(num_filters * 2, kernel_size=(3, 3), padding='same'))
    cnn_model.add(BatchNormalization())
    cnn_model.add(Activation('relu'))
    cnn_model.add(MaxPooling2D(pool_size=(2, 2)))
    
    # 第三層捲積層
    cnn_model.add(Conv2D(num_filters * 4, kernel_size=(3, 3), padding='same'))
    cnn_model.add(BatchNormalization())
    cnn_model.add(Activation('relu'))
    cnn_model.add(Conv2D(num_filters * 4, kernel_size=(3, 3), padding='same'))
    cnn_model.add(BatchNormalization())
    cnn_model.add(Activation('relu'))
    cnn_model.add(MaxPooling2D(pool_size=(2, 2)))
    
    # 展平
    cnn_model.add(Flatten())
    
    # 第一層全連接層
    cnn_model.add(Dense(dense_units))
    cnn_model.add(BatchNormalization())
    cnn_model.add(Activation('relu'))
    
    # 第二層全連接層
    cnn_model.add(Dense(dense_units * 2))
    cnn_model.add(BatchNormalization())
    cnn_model.add(Activation('relu'))
    
    # 第三層全連接層(長度同為1467個label)
    cnn_model.add(Dense(num_classes))
    
    # 表示為機率
    cnn_model.add(Activation('softmax'))

    cnn_model.compile(
        loss=keras.losses.categorical_crossentropy,
        optimizer=keras.optimizers.Adam(learning_rate=learning_rate),
        metrics=['accuracy']
    )

    return cnn_model

# %% [markdown]
# 最佳超參數

# %%
best_params = json.load(open(f"{os.getcwd()}\\best_params.json", "r"))

learning_rate = best_params["learning_rate"]
num_filters = best_params["num_filters"]
dense_units = best_params["dense_unit"]
batch_size = best_params["batch_size"]
epochs = best_params["epochs"]

# %% [markdown]
# 基本參數

# %%
channel = 1
verbose = 2
num_classes = len(label_dic)
test_size = 0.2
mfcc_dim_1 = mfcc_list.shape[1]
mfcc_dim_2 = mfcc_list.shape[2]
print(f"mfcc_dim_1: {mfcc_dim_1}")
print(f"mfcc_dim_2: {mfcc_dim_2}")
# Out:
# mfcc_dim_1: 13
# mfcc_dim_2: 44

# %% [markdown]
# 資料分割

# %%
X = mfcc_list_scaled
y = label_int_list

# 將int label轉換成二進制one hot標籤
y_one_hot = to_categorical(y, num_classes=num_classes)

X_train, X_test, y_train, y_test = train_test_split(X, y_one_hot, test_size=test_size, random_state=42)

X_train = X_train.reshape(X_train.shape[0], mfcc_dim_1, mfcc_dim_2, channel)
X_test = X_test.reshape(X_test.shape[0], mfcc_dim_1, mfcc_dim_2, channel)

# %% [markdown]
# 訓練模型

# %%
model = get_cnn_model(input_shape=(mfcc_dim_1, mfcc_dim_2, channel), num_classes=num_classes, learning_rate=learning_rate, num_filters=num_filters, dense_units=dense_units)
model_train_info = model.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, verbose=verbose, validation_data=(X_test, y_test))
# Out:
# Epoch 1/300
# 247/247 - 8s - loss: 5.3546 - accuracy: 0.1241 - val_loss: 6.8093 - val_accuracy: 0.0284 - 8s/epoch - 31ms/step
# Epoch 2/300
# 247/247 - 5s - loss: 3.8212 - accuracy: 0.2616 - val_loss: 4.3780 - val_accuracy: 0.1764 - 5s/epoch - 21ms/step
# Epoch 3/300
# 247/247 - 5s - loss: 3.1426 - accuracy: 0.3497 - val_loss: 3.3905 - val_accuracy: 0.3074 - 5s/epoch - 21ms/step
# Epoch 4/300
# 247/247 - 5s - loss: 2.6959 - accuracy: 0.4200 - val_loss: 3.0319 - val_accuracy: 0.3642 - 5s/epoch - 21ms/step
# Epoch 5/300
# 247/247 - 5s - loss: 2.3497 - accuracy: 0.4810 - val_loss: 2.8931 - val_accuracy: 0.3862 - 5s/epoch - 22ms/step
# Epoch 6/300
# 247/247 - 5s - loss: 2.0499 - accuracy: 0.5335 - val_loss: 2.6262 - val_accuracy: 0.4271 - 5s/epoch - 21ms/step
# Epoch 7/300
# 247/247 - 5s - loss: 1.7626 - accuracy: 0.5925 - val_loss: 2.5784 - val_accuracy: 0.4394 - 5s/epoch - 21ms/step
# Epoch 8/300
# 247/247 - 5s - loss: 1.4801 - accuracy: 0.6537 - val_loss: 2.5110 - val_accuracy: 0.4553 - 5s/epoch - 21ms/step
# Epoch 9/300
# 247/247 - 5s - loss: 1.1921 - accuracy: 0.7258 - val_loss: 2.4508 - val_accuracy: 0.4577 - 5s/epoch - 21ms/step
# Epoch 10/300
# 247/247 - 5s - loss: 0.9196 - accuracy: 0.7941 - val_loss: 2.4724 - val_accuracy: 0.4525 - 5s/epoch - 21ms/step
# Epoch 11/300
# 247/247 - 5s - loss: 0.6865 - accuracy: 0.8532 - val_loss: 2.4131 - val_accuracy: 0.4665 - 5s/epoch - 21ms/step
# Epoch 12/300
# 247/247 - 5s - loss: 0.5025 - accuracy: 0.8979 - val_loss: 2.3617 - val_accuracy: 0.4717 - 5s/epoch - 21ms/step
# Epoch 13/300
# 247/247 - 5s - loss: 0.3675 - accuracy: 0.9308 - val_loss: 2.4086 - val_accuracy: 0.4646 - 5s/epoch - 21ms/step
# Epoch 14/300
# 247/247 - 5s - loss: 0.2647 - accuracy: 0.9577 - val_loss: 2.3806 - val_accuracy: 0.4744 - 5s/epoch - 21ms/step
# Epoch 15/300
# 247/247 - 5s - loss: 0.1900 - accuracy: 0.9724 - val_loss: 2.4270 - val_accuracy: 0.4733 - 5s/epoch - 21ms/step
# Epoch 16/300
# 247/247 - 5s - loss: 0.1349 - accuracy: 0.9836 - val_loss: 2.4465 - val_accuracy: 0.4723 - 5s/epoch - 21ms/step
# Epoch 17/300
# 247/247 - 5s - loss: 0.0949 - accuracy: 0.9888 - val_loss: 2.4568 - val_accuracy: 0.4734 - 5s/epoch - 21ms/step
# Epoch 18/300
# 247/247 - 5s - loss: 0.0789 - accuracy: 0.9914 - val_loss: 2.4963 - val_accuracy: 0.4796 - 5s/epoch - 21ms/step
# Epoch 19/300
# 247/247 - 5s - loss: 0.0682 - accuracy: 0.9921 - val_loss: 2.5503 - val_accuracy: 0.4696 - 5s/epoch - 21ms/step
# Epoch 20/300
# 247/247 - 5s - loss: 0.0548 - accuracy: 0.9937 - val_loss: 2.5576 - val_accuracy: 0.4713 - 5s/epoch - 20ms/step
# Epoch 21/300
# 247/247 - 5s - loss: 0.0390 - accuracy: 0.9957 - val_loss: 2.6023 - val_accuracy: 0.4732 - 5s/epoch - 20ms/step
# Epoch 22/300
# 247/247 - 5s - loss: 0.0970 - accuracy: 0.9847 - val_loss: 2.8050 - val_accuracy: 0.4386 - 5s/epoch - 20ms/step
# Epoch 23/300
# 247/247 - 5s - loss: 0.1127 - accuracy: 0.9817 - val_loss: 2.7673 - val_accuracy: 0.4471 - 5s/epoch - 20ms/step
# Epoch 24/300
# 247/247 - 5s - loss: 0.0897 - accuracy: 0.9848 - val_loss: 2.6738 - val_accuracy: 0.4652 - 5s/epoch - 20ms/step
# Epoch 25/300
# 247/247 - 5s - loss: 0.0421 - accuracy: 0.9941 - val_loss: 2.6659 - val_accuracy: 0.4677 - 5s/epoch - 20ms/step
# Epoch 26/300
# 247/247 - 5s - loss: 0.0229 - accuracy: 0.9967 - val_loss: 2.6989 - val_accuracy: 0.4785 - 5s/epoch - 20ms/step
# Epoch 27/300
# 247/247 - 5s - loss: 0.0316 - accuracy: 0.9947 - val_loss: 2.7725 - val_accuracy: 0.4613 - 5s/epoch - 20ms/step
# Epoch 28/300
# 247/247 - 5s - loss: 0.0571 - accuracy: 0.9899 - val_loss: 2.9884 - val_accuracy: 0.4140 - 5s/epoch - 20ms/step
# Epoch 29/300
# 247/247 - 5s - loss: 0.0997 - accuracy: 0.9819 - val_loss: 3.0459 - val_accuracy: 0.4227 - 5s/epoch - 20ms/step
# Epoch 30/300
# 247/247 - 5s - loss: 0.0714 - accuracy: 0.9869 - val_loss: 2.9963 - val_accuracy: 0.4405 - 5s/epoch - 20ms/step
# Epoch 31/300
# 247/247 - 5s - loss: 0.0289 - accuracy: 0.9961 - val_loss: 2.7771 - val_accuracy: 0.4790 - 5s/epoch - 20ms/step
# Epoch 32/300
# 247/247 - 5s - loss: 0.0175 - accuracy: 0.9970 - val_loss: 2.8449 - val_accuracy: 0.4665 - 5s/epoch - 20ms/step
# Epoch 33/300
# 247/247 - 5s - loss: 0.0202 - accuracy: 0.9964 - val_loss: 3.0039 - val_accuracy: 0.4444 - 5s/epoch - 20ms/step
# Epoch 34/300
# 247/247 - 5s - loss: 0.0888 - accuracy: 0.9801 - val_loss: 3.2640 - val_accuracy: 0.3954 - 5s/epoch - 20ms/step
# Epoch 35/300
# 247/247 - 5s - loss: 0.0933 - accuracy: 0.9808 - val_loss: 2.9513 - val_accuracy: 0.4517 - 5s/epoch - 20ms/step
# Epoch 36/300
# 247/247 - 5s - loss: 0.0285 - accuracy: 0.9960 - val_loss: 2.9575 - val_accuracy: 0.4692 - 5s/epoch - 20ms/step
# Epoch 37/300
# 247/247 - 5s - loss: 0.0103 - accuracy: 0.9984 - val_loss: 2.8553 - val_accuracy: 0.4794 - 5s/epoch - 20ms/step
# Epoch 38/300
# 247/247 - 5s - loss: 0.0070 - accuracy: 0.9990 - val_loss: 2.8541 - val_accuracy: 0.4918 - 5s/epoch - 20ms/step
# Epoch 39/300
# 247/247 - 5s - loss: 0.0077 - accuracy: 0.9987 - val_loss: 2.8761 - val_accuracy: 0.4922 - 5s/epoch - 20ms/step
# Epoch 40/300
# 247/247 - 5s - loss: 0.0126 - accuracy: 0.9975 - val_loss: 3.2082 - val_accuracy: 0.4382 - 5s/epoch - 20ms/step
# Epoch 41/300
# 247/247 - 5s - loss: 0.1911 - accuracy: 0.9494 - val_loss: 3.4906 - val_accuracy: 0.3589 - 5s/epoch - 20ms/step
# Epoch 42/300
# 247/247 - 5s - loss: 0.1005 - accuracy: 0.9759 - val_loss: 2.9798 - val_accuracy: 0.4639 - 5s/epoch - 20ms/step
# Epoch 43/300
# 247/247 - 5s - loss: 0.0157 - accuracy: 0.9978 - val_loss: 2.9095 - val_accuracy: 0.4837 - 5s/epoch - 20ms/step
# Epoch 44/300
# 247/247 - 5s - loss: 0.0064 - accuracy: 0.9990 - val_loss: 2.8659 - val_accuracy: 0.4906 - 5s/epoch - 20ms/step
# Epoch 45/300
# 247/247 - 5s - loss: 0.0054 - accuracy: 0.9989 - val_loss: 2.9147 - val_accuracy: 0.4938 - 5s/epoch - 20ms/step
# Epoch 46/300
# 247/247 - 5s - loss: 0.0081 - accuracy: 0.9981 - val_loss: 2.9591 - val_accuracy: 0.4789 - 5s/epoch - 20ms/step
# Epoch 47/300
# 247/247 - 5s - loss: 0.0205 - accuracy: 0.9956 - val_loss: 3.1044 - val_accuracy: 0.4481 - 5s/epoch - 20ms/step
# Epoch 48/300
# 247/247 - 5s - loss: 0.0902 - accuracy: 0.9762 - val_loss: 3.4503 - val_accuracy: 0.3948 - 5s/epoch - 20ms/step
# Epoch 49/300
# 247/247 - 5s - loss: 0.0846 - accuracy: 0.9785 - val_loss: 3.1625 - val_accuracy: 0.4476 - 5s/epoch - 20ms/step
# Epoch 50/300
# 247/247 - 5s - loss: 0.0249 - accuracy: 0.9951 - val_loss: 3.1001 - val_accuracy: 0.4747 - 5s/epoch - 21ms/step
# Epoch 51/300
# 247/247 - 5s - loss: 0.0102 - accuracy: 0.9983 - val_loss: 3.0373 - val_accuracy: 0.4917 - 5s/epoch - 20ms/step
# Epoch 52/300
# 247/247 - 5s - loss: 0.0084 - accuracy: 0.9983 - val_loss: 3.0343 - val_accuracy: 0.4950 - 5s/epoch - 20ms/step
# Epoch 53/300
# 247/247 - 5s - loss: 0.0040 - accuracy: 0.9992 - val_loss: 3.0423 - val_accuracy: 0.4925 - 5s/epoch - 20ms/step
# Epoch 54/300
# 247/247 - 5s - loss: 0.0037 - accuracy: 0.9992 - val_loss: 3.0690 - val_accuracy: 0.4907 - 5s/epoch - 20ms/step
# Epoch 55/300
# 247/247 - 5s - loss: 0.0051 - accuracy: 0.9989 - val_loss: 3.1068 - val_accuracy: 0.4851 - 5s/epoch - 20ms/step
# Epoch 56/300
# 247/247 - 5s - loss: 0.0042 - accuracy: 0.9990 - val_loss: 3.0597 - val_accuracy: 0.4879 - 5s/epoch - 20ms/step
# Epoch 57/300
# 247/247 - 5s - loss: 0.0120 - accuracy: 0.9977 - val_loss: 3.3979 - val_accuracy: 0.4287 - 5s/epoch - 20ms/step
# Epoch 58/300
# 247/247 - 5s - loss: 0.2925 - accuracy: 0.9127 - val_loss: 3.2896 - val_accuracy: 0.4195 - 5s/epoch - 20ms/step
# Epoch 59/300
# 247/247 - 5s - loss: 0.0377 - accuracy: 0.9921 - val_loss: 3.1102 - val_accuracy: 0.4665 - 5s/epoch - 20ms/step
# Epoch 60/300
# 247/247 - 5s - loss: 0.0094 - accuracy: 0.9984 - val_loss: 3.0821 - val_accuracy: 0.4862 - 5s/epoch - 20ms/step
# Epoch 61/300
# 247/247 - 5s - loss: 0.0039 - accuracy: 0.9993 - val_loss: 3.0305 - val_accuracy: 0.4942 - 5s/epoch - 20ms/step
# Epoch 62/300
# 247/247 - 5s - loss: 0.0031 - accuracy: 0.9993 - val_loss: 3.0459 - val_accuracy: 0.4941 - 5s/epoch - 20ms/step
# Epoch 63/300
# 247/247 - 5s - loss: 0.0026 - accuracy: 0.9993 - val_loss: 3.0746 - val_accuracy: 0.4956 - 5s/epoch - 20ms/step
# Epoch 64/300
# 247/247 - 5s - loss: 0.0024 - accuracy: 0.9992 - val_loss: 3.0652 - val_accuracy: 0.4973 - 5s/epoch - 20ms/step
# Epoch 65/300
# 247/247 - 5s - loss: 0.0023 - accuracy: 0.9992 - val_loss: 3.0701 - val_accuracy: 0.4980 - 5s/epoch - 20ms/step
# Epoch 66/300
# 247/247 - 5s - loss: 0.0024 - accuracy: 0.9992 - val_loss: 3.0918 - val_accuracy: 0.4988 - 5s/epoch - 20ms/step
# Epoch 67/300
# 247/247 - 5s - loss: 0.0022 - accuracy: 0.9993 - val_loss: 3.1039 - val_accuracy: 0.4936 - 5s/epoch - 20ms/step
# Epoch 68/300
# 247/247 - 5s - loss: 0.0023 - accuracy: 0.9993 - val_loss: 3.1030 - val_accuracy: 0.4964 - 5s/epoch - 20ms/step
# Epoch 69/300
# 247/247 - 5s - loss: 0.0023 - accuracy: 0.9993 - val_loss: 3.1167 - val_accuracy: 0.4996 - 5s/epoch - 20ms/step
# Epoch 70/300
# 247/247 - 5s - loss: 0.0024 - accuracy: 0.9993 - val_loss: 3.1098 - val_accuracy: 0.4963 - 5s/epoch - 20ms/step
# Epoch 71/300
# 247/247 - 5s - loss: 0.0025 - accuracy: 0.9993 - val_loss: 3.1617 - val_accuracy: 0.4960 - 5s/epoch - 20ms/step
# Epoch 72/300
# 247/247 - 5s - loss: 0.0026 - accuracy: 0.9992 - val_loss: 3.1545 - val_accuracy: 0.4947 - 5s/epoch - 20ms/step
# Epoch 73/300
# 247/247 - 5s - loss: 0.3565 - accuracy: 0.8912 - val_loss: 3.7363 - val_accuracy: 0.3783 - 5s/epoch - 20ms/step
# Epoch 74/300
# 247/247 - 5s - loss: 0.0714 - accuracy: 0.9808 - val_loss: 3.1825 - val_accuracy: 0.4656 - 5s/epoch - 20ms/step
# Epoch 75/300
# 247/247 - 5s - loss: 0.0109 - accuracy: 0.9988 - val_loss: 3.0681 - val_accuracy: 0.4928 - 5s/epoch - 20ms/step
# Epoch 76/300
# 247/247 - 5s - loss: 0.0054 - accuracy: 0.9989 - val_loss: 3.0582 - val_accuracy: 0.4926 - 5s/epoch - 20ms/step
# Epoch 77/300
# 247/247 - 5s - loss: 0.0058 - accuracy: 0.9985 - val_loss: 3.0893 - val_accuracy: 0.4935 - 5s/epoch - 20ms/step
# Epoch 78/300
# 247/247 - 5s - loss: 0.0037 - accuracy: 0.9990 - val_loss: 3.1614 - val_accuracy: 0.4930 - 5s/epoch - 20ms/step
# Epoch 79/300
# 247/247 - 5s - loss: 0.0039 - accuracy: 0.9992 - val_loss: 3.1096 - val_accuracy: 0.4984 - 5s/epoch - 20ms/step
# Epoch 80/300
# 247/247 - 5s - loss: 0.0026 - accuracy: 0.9991 - val_loss: 3.0956 - val_accuracy: 0.4964 - 5s/epoch - 20ms/step
# Epoch 81/300
# 247/247 - 5s - loss: 0.0025 - accuracy: 0.9992 - val_loss: 3.1444 - val_accuracy: 0.5006 - 5s/epoch - 20ms/step
# Epoch 82/300
# 247/247 - 5s - loss: 0.0020 - accuracy: 0.9993 - val_loss: 3.1175 - val_accuracy: 0.4983 - 5s/epoch - 20ms/step
# Epoch 83/300
# 247/247 - 5s - loss: 0.0020 - accuracy: 0.9992 - val_loss: 3.1508 - val_accuracy: 0.4980 - 5s/epoch - 20ms/step
# Epoch 84/300
# 247/247 - 5s - loss: 0.0019 - accuracy: 0.9993 - val_loss: 3.1229 - val_accuracy: 0.4982 - 5s/epoch - 20ms/step
# Epoch 85/300
# 247/247 - 5s - loss: 0.0021 - accuracy: 0.9992 - val_loss: 3.1682 - val_accuracy: 0.4980 - 5s/epoch - 20ms/step
# Epoch 86/300
# 247/247 - 5s - loss: 0.0062 - accuracy: 0.9985 - val_loss: 3.4292 - val_accuracy: 0.4318 - 5s/epoch - 20ms/step
# Epoch 87/300
# 247/247 - 5s - loss: 0.3140 - accuracy: 0.9022 - val_loss: 3.4110 - val_accuracy: 0.4372 - 5s/epoch - 20ms/step
# Epoch 88/300
# 247/247 - 5s - loss: 0.0401 - accuracy: 0.9906 - val_loss: 3.1428 - val_accuracy: 0.4777 - 5s/epoch - 20ms/step
# Epoch 89/300
# 247/247 - 5s - loss: 0.0103 - accuracy: 0.9979 - val_loss: 3.2067 - val_accuracy: 0.4890 - 5s/epoch - 20ms/step
# Epoch 90/300
# 247/247 - 5s - loss: 0.0049 - accuracy: 0.9990 - val_loss: 3.1699 - val_accuracy: 0.4997 - 5s/epoch - 20ms/step
# Epoch 91/300
# 247/247 - 5s - loss: 0.0027 - accuracy: 0.9993 - val_loss: 3.1612 - val_accuracy: 0.4998 - 5s/epoch - 20ms/step
# Epoch 92/300
# 247/247 - 5s - loss: 0.0024 - accuracy: 0.9992 - val_loss: 3.1787 - val_accuracy: 0.5011 - 5s/epoch - 20ms/step
# Epoch 93/300
# 247/247 - 5s - loss: 0.0021 - accuracy: 0.9993 - val_loss: 3.1702 - val_accuracy: 0.5020 - 5s/epoch - 20ms/step
# Epoch 94/300
# 247/247 - 5s - loss: 0.0019 - accuracy: 0.9994 - val_loss: 3.1919 - val_accuracy: 0.5020 - 5s/epoch - 20ms/step
# Epoch 95/300
# 247/247 - 5s - loss: 0.0018 - accuracy: 0.9993 - val_loss: 3.1930 - val_accuracy: 0.5034 - 5s/epoch - 20ms/step
# Epoch 96/300
# 247/247 - 5s - loss: 0.0040 - accuracy: 0.9990 - val_loss: 3.2658 - val_accuracy: 0.4782 - 5s/epoch - 20ms/step
# Epoch 97/300
# 247/247 - 5s - loss: 0.1462 - accuracy: 0.9563 - val_loss: 3.8183 - val_accuracy: 0.3912 - 5s/epoch - 20ms/step
# Epoch 98/300
# 247/247 - 5s - loss: 0.0798 - accuracy: 0.9765 - val_loss: 3.3389 - val_accuracy: 0.4554 - 5s/epoch - 20ms/step
# Epoch 99/300
# 247/247 - 5s - loss: 0.0146 - accuracy: 0.9969 - val_loss: 3.2412 - val_accuracy: 0.4879 - 5s/epoch - 20ms/step
# Epoch 100/300
# 247/247 - 5s - loss: 0.0061 - accuracy: 0.9988 - val_loss: 3.1817 - val_accuracy: 0.4949 - 5s/epoch - 20ms/step
# Epoch 101/300
# 247/247 - 5s - loss: 0.0029 - accuracy: 0.9993 - val_loss: 3.2280 - val_accuracy: 0.4956 - 5s/epoch - 20ms/step
# Epoch 102/300
# 247/247 - 5s - loss: 0.0021 - accuracy: 0.9993 - val_loss: 3.2599 - val_accuracy: 0.4958 - 5s/epoch - 20ms/step
# Epoch 103/300
# 247/247 - 5s - loss: 0.0019 - accuracy: 0.9994 - val_loss: 3.2451 - val_accuracy: 0.4968 - 5s/epoch - 20ms/step
# Epoch 104/300
# 247/247 - 5s - loss: 0.0018 - accuracy: 0.9991 - val_loss: 3.2589 - val_accuracy: 0.4992 - 5s/epoch - 20ms/step
# Epoch 105/300
# 247/247 - 5s - loss: 0.0017 - accuracy: 0.9992 - val_loss: 3.2850 - val_accuracy: 0.4974 - 5s/epoch - 20ms/step
# Epoch 106/300
# 247/247 - 5s - loss: 0.0017 - accuracy: 0.9992 - val_loss: 3.2359 - val_accuracy: 0.4985 - 5s/epoch - 20ms/step
# Epoch 107/300
# 247/247 - 5s - loss: 0.0017 - accuracy: 0.9994 - val_loss: 3.3292 - val_accuracy: 0.4974 - 5s/epoch - 20ms/step
# Epoch 108/300
# 247/247 - 5s - loss: 0.0017 - accuracy: 0.9992 - val_loss: 3.2395 - val_accuracy: 0.4960 - 5s/epoch - 20ms/step
# Epoch 109/300
# 247/247 - 5s - loss: 0.0017 - accuracy: 0.9994 - val_loss: 3.3774 - val_accuracy: 0.4994 - 5s/epoch - 20ms/step
# Epoch 110/300
# 247/247 - 5s - loss: 0.0017 - accuracy: 0.9993 - val_loss: 3.2661 - val_accuracy: 0.4970 - 5s/epoch - 20ms/step
# Epoch 111/300
# 247/247 - 5s - loss: 0.0017 - accuracy: 0.9993 - val_loss: 3.3368 - val_accuracy: 0.4978 - 5s/epoch - 20ms/step
# Epoch 112/300
# 247/247 - 5s - loss: 0.1531 - accuracy: 0.9536 - val_loss: 5.6768 - val_accuracy: 0.2699 - 5s/epoch - 20ms/step
# Epoch 113/300
# 247/247 - 5s - loss: 0.1553 - accuracy: 0.9517 - val_loss: 3.3546 - val_accuracy: 0.4572 - 5s/epoch - 20ms/step
# Epoch 114/300
# 247/247 - 5s - loss: 0.0144 - accuracy: 0.9971 - val_loss: 3.2611 - val_accuracy: 0.4900 - 5s/epoch - 20ms/step
# Epoch 115/300
# 247/247 - 5s - loss: 0.0053 - accuracy: 0.9989 - val_loss: 3.2535 - val_accuracy: 0.4949 - 5s/epoch - 20ms/step
# Epoch 116/300
# 247/247 - 5s - loss: 0.0029 - accuracy: 0.9992 - val_loss: 3.2603 - val_accuracy: 0.4971 - 5s/epoch - 20ms/step
# Epoch 117/300
# 247/247 - 5s - loss: 0.0022 - accuracy: 0.9994 - val_loss: 3.2713 - val_accuracy: 0.5001 - 5s/epoch - 20ms/step
# Epoch 118/300
# 247/247 - 5s - loss: 0.0019 - accuracy: 0.9992 - val_loss: 3.2875 - val_accuracy: 0.5026 - 5s/epoch - 20ms/step
# Epoch 119/300
# 247/247 - 5s - loss: 0.0018 - accuracy: 0.9993 - val_loss: 3.2865 - val_accuracy: 0.5029 - 5s/epoch - 20ms/step
# Epoch 120/300
# 247/247 - 5s - loss: 0.0017 - accuracy: 0.9994 - val_loss: 3.3086 - val_accuracy: 0.5004 - 5s/epoch - 20ms/step
# Epoch 121/300
# 247/247 - 5s - loss: 0.0016 - accuracy: 0.9993 - val_loss: 3.2937 - val_accuracy: 0.5025 - 5s/epoch - 20ms/step
# Epoch 122/300
# 247/247 - 5s - loss: 0.0016 - accuracy: 0.9992 - val_loss: 3.2952 - val_accuracy: 0.4996 - 5s/epoch - 20ms/step
# Epoch 123/300
# 247/247 - 5s - loss: 0.0015 - accuracy: 0.9993 - val_loss: 3.3333 - val_accuracy: 0.5025 - 5s/epoch - 20ms/step
# Epoch 124/300
# 247/247 - 5s - loss: 0.0015 - accuracy: 0.9992 - val_loss: 3.3316 - val_accuracy: 0.5029 - 5s/epoch - 20ms/step
# Epoch 125/300
# 247/247 - 5s - loss: 0.0014 - accuracy: 0.9993 - val_loss: 3.3463 - val_accuracy: 0.5023 - 5s/epoch - 20ms/step
# Epoch 126/300
# 247/247 - 5s - loss: 0.0014 - accuracy: 0.9994 - val_loss: 3.3335 - val_accuracy: 0.5032 - 5s/epoch - 20ms/step
# Epoch 127/300
# 247/247 - 5s - loss: 0.0016 - accuracy: 0.9993 - val_loss: 3.3371 - val_accuracy: 0.5012 - 5s/epoch - 20ms/step
# Epoch 128/300
# 247/247 - 5s - loss: 0.0020 - accuracy: 0.9992 - val_loss: 3.4765 - val_accuracy: 0.4988 - 5s/epoch - 20ms/step
# Epoch 129/300
# 247/247 - 5s - loss: 0.0018 - accuracy: 0.9993 - val_loss: 3.5413 - val_accuracy: 0.4954 - 5s/epoch - 20ms/step
# Epoch 130/300
# 247/247 - 5s - loss: 0.0018 - accuracy: 0.9992 - val_loss: 3.4289 - val_accuracy: 0.4955 - 5s/epoch - 20ms/step
# Epoch 131/300
# 247/247 - 5s - loss: 0.0019 - accuracy: 0.9994 - val_loss: 3.3454 - val_accuracy: 0.4999 - 5s/epoch - 20ms/step
# Epoch 132/300
# 247/247 - 5s - loss: 0.2138 - accuracy: 0.9343 - val_loss: 4.0126 - val_accuracy: 0.3944 - 5s/epoch - 20ms/step
# Epoch 133/300
# 247/247 - 5s - loss: 0.0856 - accuracy: 0.9754 - val_loss: 3.2888 - val_accuracy: 0.4713 - 5s/epoch - 20ms/step
# Epoch 134/300
# 247/247 - 5s - loss: 0.0109 - accuracy: 0.9980 - val_loss: 3.3426 - val_accuracy: 0.4892 - 5s/epoch - 20ms/step
# Epoch 135/300
# 247/247 - 5s - loss: 0.0040 - accuracy: 0.9991 - val_loss: 3.2905 - val_accuracy: 0.4907 - 5s/epoch - 20ms/step
# Epoch 136/300
# 247/247 - 5s - loss: 0.0023 - accuracy: 0.9993 - val_loss: 3.3015 - val_accuracy: 0.4946 - 5s/epoch - 20ms/step
# Epoch 137/300
# 247/247 - 5s - loss: 0.0019 - accuracy: 0.9993 - val_loss: 3.3133 - val_accuracy: 0.4942 - 5s/epoch - 20ms/step
# Epoch 138/300
# 247/247 - 5s - loss: 0.0018 - accuracy: 0.9992 - val_loss: 3.3099 - val_accuracy: 0.4944 - 5s/epoch - 20ms/step
# Epoch 139/300
# 247/247 - 5s - loss: 0.0017 - accuracy: 0.9993 - val_loss: 3.3525 - val_accuracy: 0.4960 - 5s/epoch - 20ms/step
# Epoch 140/300
# 247/247 - 5s - loss: 0.0016 - accuracy: 0.9994 - val_loss: 3.3375 - val_accuracy: 0.4941 - 5s/epoch - 20ms/step
# Epoch 141/300
# 247/247 - 5s - loss: 0.0015 - accuracy: 0.9993 - val_loss: 3.3287 - val_accuracy: 0.4961 - 5s/epoch - 20ms/step
# Epoch 142/300
# 247/247 - 5s - loss: 0.0015 - accuracy: 0.9993 - val_loss: 3.3621 - val_accuracy: 0.4977 - 5s/epoch - 20ms/step
# Epoch 143/300
# 247/247 - 5s - loss: 0.0024 - accuracy: 0.9990 - val_loss: 3.3667 - val_accuracy: 0.4908 - 5s/epoch - 20ms/step
# Epoch 144/300
# 247/247 - 5s - loss: 0.0040 - accuracy: 0.9989 - val_loss: 3.6398 - val_accuracy: 0.4767 - 5s/epoch - 20ms/step
# Epoch 145/300
# 247/247 - 5s - loss: 0.1794 - accuracy: 0.9451 - val_loss: 4.2425 - val_accuracy: 0.3778 - 5s/epoch - 20ms/step
# Epoch 146/300
# 247/247 - 5s - loss: 0.0394 - accuracy: 0.9896 - val_loss: 3.4635 - val_accuracy: 0.4704 - 5s/epoch - 20ms/step
# Epoch 147/300
# 247/247 - 5s - loss: 0.0080 - accuracy: 0.9985 - val_loss: 3.4504 - val_accuracy: 0.4841 - 5s/epoch - 20ms/step
# Epoch 148/300
# 247/247 - 5s - loss: 0.0042 - accuracy: 0.9988 - val_loss: 3.4035 - val_accuracy: 0.4888 - 5s/epoch - 20ms/step
# Epoch 149/300
# 247/247 - 5s - loss: 0.0031 - accuracy: 0.9989 - val_loss: 3.3823 - val_accuracy: 0.4857 - 5s/epoch - 20ms/step
# Epoch 150/300
# 247/247 - 5s - loss: 0.0031 - accuracy: 0.9990 - val_loss: 3.4516 - val_accuracy: 0.4908 - 5s/epoch - 20ms/step
# Epoch 151/300
# 247/247 - 5s - loss: 0.0030 - accuracy: 0.9988 - val_loss: 3.4471 - val_accuracy: 0.4881 - 5s/epoch - 20ms/step
# Epoch 152/300
# 247/247 - 5s - loss: 0.0028 - accuracy: 0.9990 - val_loss: 3.4808 - val_accuracy: 0.4878 - 5s/epoch - 20ms/step
# Epoch 153/300
# 247/247 - 5s - loss: 0.0033 - accuracy: 0.9990 - val_loss: 3.5355 - val_accuracy: 0.4744 - 5s/epoch - 20ms/step
# Epoch 154/300
# 247/247 - 5s - loss: 0.0544 - accuracy: 0.9847 - val_loss: 4.1290 - val_accuracy: 0.3973 - 5s/epoch - 20ms/step
# Epoch 155/300
# 247/247 - 5s - loss: 0.0656 - accuracy: 0.9809 - val_loss: 3.7855 - val_accuracy: 0.4382 - 5s/epoch - 20ms/step
# Epoch 156/300
# 247/247 - 5s - loss: 0.0271 - accuracy: 0.9926 - val_loss: 3.5480 - val_accuracy: 0.4619 - 5s/epoch - 20ms/step
# Epoch 157/300
# 247/247 - 5s - loss: 0.0082 - accuracy: 0.9979 - val_loss: 3.5353 - val_accuracy: 0.4847 - 5s/epoch - 20ms/step
# Epoch 158/300
# 247/247 - 5s - loss: 0.0067 - accuracy: 0.9982 - val_loss: 3.5139 - val_accuracy: 0.4843 - 5s/epoch - 20ms/step
# Epoch 159/300
# 247/247 - 5s - loss: 0.0094 - accuracy: 0.9976 - val_loss: 3.6967 - val_accuracy: 0.4785 - 5s/epoch - 20ms/step
# Epoch 160/300
# 247/247 - 5s - loss: 0.0087 - accuracy: 0.9977 - val_loss: 3.5794 - val_accuracy: 0.4782 - 5s/epoch - 20ms/step
# Epoch 161/300
# 247/247 - 5s - loss: 0.0057 - accuracy: 0.9985 - val_loss: 3.6926 - val_accuracy: 0.4819 - 5s/epoch - 20ms/step
# Epoch 162/300
# 247/247 - 5s - loss: 0.0095 - accuracy: 0.9973 - val_loss: 3.6328 - val_accuracy: 0.4762 - 5s/epoch - 20ms/step
# Epoch 163/300
# 247/247 - 5s - loss: 0.0166 - accuracy: 0.9957 - val_loss: 3.9395 - val_accuracy: 0.4448 - 5s/epoch - 20ms/step
# Epoch 164/300
# 247/247 - 5s - loss: 0.0560 - accuracy: 0.9837 - val_loss: 4.3813 - val_accuracy: 0.3952 - 5s/epoch - 20ms/step
# Epoch 165/300
# 247/247 - 5s - loss: 0.0353 - accuracy: 0.9899 - val_loss: 3.8431 - val_accuracy: 0.4521 - 5s/epoch - 20ms/step
# Epoch 166/300
# 247/247 - 5s - loss: 0.0119 - accuracy: 0.9973 - val_loss: 3.8439 - val_accuracy: 0.4771 - 5s/epoch - 20ms/step
# Epoch 167/300
# 247/247 - 5s - loss: 0.0042 - accuracy: 0.9988 - val_loss: 3.7070 - val_accuracy: 0.4837 - 5s/epoch - 20ms/step
# Epoch 168/300
# 247/247 - 5s - loss: 0.0042 - accuracy: 0.9985 - val_loss: 3.6050 - val_accuracy: 0.4867 - 5s/epoch - 20ms/step
# Epoch 169/300
# 247/247 - 5s - loss: 0.0071 - accuracy: 0.9981 - val_loss: 3.6069 - val_accuracy: 0.4774 - 5s/epoch - 20ms/step
# Epoch 170/300
# 247/247 - 5s - loss: 0.0073 - accuracy: 0.9979 - val_loss: 3.7238 - val_accuracy: 0.4763 - 5s/epoch - 20ms/step
# Epoch 171/300
# 247/247 - 5s - loss: 0.0086 - accuracy: 0.9977 - val_loss: 3.8138 - val_accuracy: 0.4621 - 5s/epoch - 20ms/step
# Epoch 172/300
# 247/247 - 5s - loss: 0.0324 - accuracy: 0.9908 - val_loss: 4.6941 - val_accuracy: 0.3914 - 5s/epoch - 20ms/step
# Epoch 173/300
# 247/247 - 5s - loss: 0.0408 - accuracy: 0.9879 - val_loss: 3.6038 - val_accuracy: 0.4558 - 5s/epoch - 20ms/step
# Epoch 174/300
# 247/247 - 5s - loss: 0.0190 - accuracy: 0.9945 - val_loss: 3.6276 - val_accuracy: 0.4803 - 5s/epoch - 20ms/step
# Epoch 175/300
# 247/247 - 5s - loss: 0.0055 - accuracy: 0.9983 - val_loss: 3.7914 - val_accuracy: 0.4818 - 5s/epoch - 20ms/step
# Epoch 176/300
# 247/247 - 5s - loss: 0.0037 - accuracy: 0.9988 - val_loss: 3.7199 - val_accuracy: 0.4873 - 5s/epoch - 20ms/step
# Epoch 177/300
# 247/247 - 5s - loss: 0.0025 - accuracy: 0.9990 - val_loss: 3.8478 - val_accuracy: 0.4837 - 5s/epoch - 20ms/step
# Epoch 178/300
# 247/247 - 5s - loss: 0.0056 - accuracy: 0.9982 - val_loss: 3.7215 - val_accuracy: 0.4831 - 5s/epoch - 20ms/step
# Epoch 179/300
# 247/247 - 5s - loss: 0.0050 - accuracy: 0.9984 - val_loss: 3.8442 - val_accuracy: 0.4637 - 5s/epoch - 20ms/step
# Epoch 180/300
# 247/247 - 5s - loss: 0.0495 - accuracy: 0.9857 - val_loss: 4.1235 - val_accuracy: 0.4137 - 5s/epoch - 20ms/step
# Epoch 181/300
# 247/247 - 5s - loss: 0.0337 - accuracy: 0.9902 - val_loss: 4.0096 - val_accuracy: 0.4511 - 5s/epoch - 20ms/step
# Epoch 182/300
# 247/247 - 5s - loss: 0.0120 - accuracy: 0.9967 - val_loss: 3.7864 - val_accuracy: 0.4588 - 5s/epoch - 20ms/step
# Epoch 183/300
# 247/247 - 5s - loss: 0.0077 - accuracy: 0.9979 - val_loss: 3.8576 - val_accuracy: 0.4706 - 5s/epoch - 20ms/step
# Epoch 184/300
# 247/247 - 5s - loss: 0.0051 - accuracy: 0.9987 - val_loss: 3.8291 - val_accuracy: 0.4829 - 5s/epoch - 20ms/step
# Epoch 185/300
# 247/247 - 5s - loss: 0.0020 - accuracy: 0.9991 - val_loss: 3.7041 - val_accuracy: 0.4925 - 5s/epoch - 20ms/step
# Epoch 186/300
# 247/247 - 5s - loss: 0.0014 - accuracy: 0.9992 - val_loss: 3.7402 - val_accuracy: 0.4931 - 5s/epoch - 20ms/step
# Epoch 187/300
# 247/247 - 5s - loss: 0.0012 - accuracy: 0.9993 - val_loss: 3.7402 - val_accuracy: 0.4938 - 5s/epoch - 20ms/step
# Epoch 188/300
# 247/247 - 5s - loss: 0.0012 - accuracy: 0.9993 - val_loss: 3.7479 - val_accuracy: 0.4954 - 5s/epoch - 20ms/step
# Epoch 189/300
# 247/247 - 5s - loss: 0.0011 - accuracy: 0.9991 - val_loss: 3.7431 - val_accuracy: 0.4956 - 5s/epoch - 20ms/step
# Epoch 190/300
# 247/247 - 5s - loss: 0.0011 - accuracy: 0.9992 - val_loss: 3.7503 - val_accuracy: 0.4941 - 5s/epoch - 20ms/step
# Epoch 191/300
# 247/247 - 5s - loss: 0.0011 - accuracy: 0.9993 - val_loss: 3.8008 - val_accuracy: 0.4928 - 5s/epoch - 20ms/step
# Epoch 192/300
# 247/247 - 5s - loss: 0.0011 - accuracy: 0.9993 - val_loss: 3.8549 - val_accuracy: 0.4973 - 5s/epoch - 20ms/step
# Epoch 193/300
# 247/247 - 5s - loss: 0.0011 - accuracy: 0.9994 - val_loss: 3.7721 - val_accuracy: 0.4969 - 5s/epoch - 20ms/step
# Epoch 194/300
# 247/247 - 5s - loss: 0.0011 - accuracy: 0.9993 - val_loss: 3.8151 - val_accuracy: 0.4977 - 5s/epoch - 20ms/step
# Epoch 195/300
# 247/247 - 5s - loss: 0.0012 - accuracy: 0.9994 - val_loss: 3.8980 - val_accuracy: 0.4960 - 5s/epoch - 20ms/step
# Epoch 196/300
# 247/247 - 5s - loss: 0.0011 - accuracy: 0.9994 - val_loss: 3.8110 - val_accuracy: 0.4968 - 5s/epoch - 20ms/step
# Epoch 197/300
# 247/247 - 5s - loss: 0.0013 - accuracy: 0.9993 - val_loss: 3.7804 - val_accuracy: 0.4927 - 5s/epoch - 20ms/step
# Epoch 198/300
# 247/247 - 5s - loss: 0.0728 - accuracy: 0.9791 - val_loss: 4.6262 - val_accuracy: 0.3276 - 5s/epoch - 20ms/step
# Epoch 199/300
# 247/247 - 5s - loss: 0.1114 - accuracy: 0.9650 - val_loss: 3.7212 - val_accuracy: 0.4578 - 5s/epoch - 20ms/step
# Epoch 200/300
# 247/247 - 5s - loss: 0.0081 - accuracy: 0.9982 - val_loss: 3.7002 - val_accuracy: 0.4916 - 5s/epoch - 20ms/step
# Epoch 201/300
# 247/247 - 5s - loss: 0.0024 - accuracy: 0.9993 - val_loss: 3.7253 - val_accuracy: 0.4955 - 5s/epoch - 20ms/step
# Epoch 202/300
# 247/247 - 5s - loss: 0.0017 - accuracy: 0.9994 - val_loss: 3.7083 - val_accuracy: 0.4964 - 5s/epoch - 20ms/step
# Epoch 203/300
# 247/247 - 5s - loss: 0.0015 - accuracy: 0.9993 - val_loss: 3.7018 - val_accuracy: 0.4973 - 5s/epoch - 20ms/step
# Epoch 204/300
# 247/247 - 5s - loss: 0.0014 - accuracy: 0.9993 - val_loss: 3.7165 - val_accuracy: 0.4978 - 5s/epoch - 20ms/step
# Epoch 205/300
# 247/247 - 5s - loss: 0.0013 - accuracy: 0.9993 - val_loss: 3.7192 - val_accuracy: 0.4978 - 5s/epoch - 20ms/step
# Epoch 206/300
# 247/247 - 5s - loss: 0.0012 - accuracy: 0.9993 - val_loss: 3.7249 - val_accuracy: 0.4989 - 5s/epoch - 20ms/step
# Epoch 207/300
# 247/247 - 5s - loss: 0.0012 - accuracy: 0.9993 - val_loss: 3.7433 - val_accuracy: 0.4983 - 5s/epoch - 20ms/step
# Epoch 208/300
# 247/247 - 5s - loss: 0.0011 - accuracy: 0.9992 - val_loss: 3.7442 - val_accuracy: 0.4996 - 5s/epoch - 20ms/step
# Epoch 209/300
# 247/247 - 5s - loss: 0.0011 - accuracy: 0.9992 - val_loss: 3.7473 - val_accuracy: 0.4987 - 5s/epoch - 20ms/step
# Epoch 210/300
# 247/247 - 5s - loss: 0.0011 - accuracy: 0.9992 - val_loss: 3.7673 - val_accuracy: 0.4983 - 5s/epoch - 20ms/step
# Epoch 211/300
# 247/247 - 5s - loss: 0.0011 - accuracy: 0.9994 - val_loss: 3.7740 - val_accuracy: 0.4979 - 5s/epoch - 20ms/step
# Epoch 212/300
# 247/247 - 5s - loss: 0.0010 - accuracy: 0.9994 - val_loss: 3.7388 - val_accuracy: 0.5003 - 5s/epoch - 20ms/step
# Epoch 213/300
# 247/247 - 5s - loss: 0.0010 - accuracy: 0.9991 - val_loss: 3.7898 - val_accuracy: 0.5001 - 5s/epoch - 20ms/step
# Epoch 214/300
# 247/247 - 5s - loss: 0.0011 - accuracy: 0.9994 - val_loss: 3.8152 - val_accuracy: 0.5021 - 5s/epoch - 20ms/step
# Epoch 215/300
# 247/247 - 5s - loss: 0.0010 - accuracy: 0.9993 - val_loss: 3.7623 - val_accuracy: 0.5011 - 5s/epoch - 20ms/step
# Epoch 216/300
# 247/247 - 5s - loss: 0.0011 - accuracy: 0.9993 - val_loss: 3.7763 - val_accuracy: 0.5016 - 5s/epoch - 20ms/step
# Epoch 217/300
# 247/247 - 5s - loss: 0.0011 - accuracy: 0.9994 - val_loss: 3.8742 - val_accuracy: 0.4992 - 5s/epoch - 20ms/step
# Epoch 218/300
# 247/247 - 5s - loss: 0.0012 - accuracy: 0.9993 - val_loss: 3.8504 - val_accuracy: 0.5030 - 5s/epoch - 20ms/step
# Epoch 219/300
# 247/247 - 5s - loss: 0.0012 - accuracy: 0.9992 - val_loss: 3.8166 - val_accuracy: 0.4997 - 5s/epoch - 20ms/step
# Epoch 220/300
# 247/247 - 5s - loss: 0.0012 - accuracy: 0.9994 - val_loss: 3.9419 - val_accuracy: 0.4938 - 5s/epoch - 20ms/step
# Epoch 221/300
# 247/247 - 5s - loss: 0.0640 - accuracy: 0.9813 - val_loss: 6.9261 - val_accuracy: 0.2419 - 5s/epoch - 20ms/step
# Epoch 222/300
# 247/247 - 5s - loss: 0.1335 - accuracy: 0.9586 - val_loss: 3.9926 - val_accuracy: 0.4444 - 5s/epoch - 20ms/step
# Epoch 223/300
# 247/247 - 5s - loss: 0.0101 - accuracy: 0.9974 - val_loss: 3.7629 - val_accuracy: 0.4860 - 5s/epoch - 20ms/step
# Epoch 224/300
# 247/247 - 5s - loss: 0.0026 - accuracy: 0.9993 - val_loss: 3.7533 - val_accuracy: 0.4927 - 5s/epoch - 20ms/step
# Epoch 225/300
# 247/247 - 5s - loss: 0.0017 - accuracy: 0.9993 - val_loss: 3.7409 - val_accuracy: 0.4963 - 5s/epoch - 20ms/step
# Epoch 226/300
# 247/247 - 5s - loss: 0.0015 - accuracy: 0.9993 - val_loss: 3.7476 - val_accuracy: 0.4954 - 5s/epoch - 20ms/step
# Epoch 227/300
# 247/247 - 5s - loss: 0.0014 - accuracy: 0.9994 - val_loss: 3.7436 - val_accuracy: 0.4977 - 5s/epoch - 20ms/step
# Epoch 228/300
# 247/247 - 5s - loss: 0.0013 - accuracy: 0.9992 - val_loss: 3.7540 - val_accuracy: 0.4982 - 5s/epoch - 20ms/step
# Epoch 229/300
# 247/247 - 5s - loss: 0.0012 - accuracy: 0.9993 - val_loss: 3.7495 - val_accuracy: 0.4990 - 5s/epoch - 20ms/step
# Epoch 230/300
# 247/247 - 5s - loss: 0.0012 - accuracy: 0.9993 - val_loss: 3.7705 - val_accuracy: 0.5006 - 5s/epoch - 20ms/step
# Epoch 231/300
# 247/247 - 5s - loss: 0.0011 - accuracy: 0.9991 - val_loss: 3.7775 - val_accuracy: 0.4989 - 5s/epoch - 20ms/step
# Epoch 232/300
# 247/247 - 5s - loss: 0.0011 - accuracy: 0.9993 - val_loss: 3.7826 - val_accuracy: 0.4994 - 5s/epoch - 20ms/step
# Epoch 233/300
# 247/247 - 5s - loss: 0.0011 - accuracy: 0.9993 - val_loss: 3.7812 - val_accuracy: 0.5013 - 5s/epoch - 20ms/step
# Epoch 234/300
# 247/247 - 5s - loss: 0.0011 - accuracy: 0.9992 - val_loss: 3.7614 - val_accuracy: 0.4999 - 5s/epoch - 20ms/step
# Epoch 235/300
# 247/247 - 5s - loss: 0.0010 - accuracy: 0.9993 - val_loss: 3.8160 - val_accuracy: 0.5020 - 5s/epoch - 20ms/step
# Epoch 236/300
# 247/247 - 5s - loss: 0.0010 - accuracy: 0.9993 - val_loss: 3.7869 - val_accuracy: 0.5017 - 5s/epoch - 20ms/step
# Epoch 237/300
# 247/247 - 5s - loss: 9.7609e-04 - accuracy: 0.9992 - val_loss: 3.8284 - val_accuracy: 0.5022 - 5s/epoch - 20ms/step
# Epoch 238/300
# 247/247 - 5s - loss: 0.0010 - accuracy: 0.9993 - val_loss: 3.8296 - val_accuracy: 0.5036 - 5s/epoch - 20ms/step
# Epoch 239/300
# 247/247 - 5s - loss: 9.8194e-04 - accuracy: 0.9993 - val_loss: 3.8033 - val_accuracy: 0.5025 - 5s/epoch - 20ms/step
# Epoch 240/300
# 247/247 - 5s - loss: 9.8407e-04 - accuracy: 0.9992 - val_loss: 3.8319 - val_accuracy: 0.5022 - 5s/epoch - 20ms/step
# Epoch 241/300
# 247/247 - 5s - loss: 9.7881e-04 - accuracy: 0.9993 - val_loss: 3.8351 - val_accuracy: 0.5049 - 5s/epoch - 20ms/step
# Epoch 242/300
# 247/247 - 5s - loss: 0.0011 - accuracy: 0.9992 - val_loss: 4.0909 - val_accuracy: 0.4942 - 5s/epoch - 20ms/step
# Epoch 243/300
# 247/247 - 5s - loss: 0.0011 - accuracy: 0.9993 - val_loss: 3.7478 - val_accuracy: 0.5017 - 5s/epoch - 20ms/step
# Epoch 244/300
# 247/247 - 5s - loss: 0.0012 - accuracy: 0.9994 - val_loss: 3.9179 - val_accuracy: 0.4977 - 5s/epoch - 20ms/step
# Epoch 245/300
# 247/247 - 5s - loss: 0.1487 - accuracy: 0.9537 - val_loss: 4.4592 - val_accuracy: 0.3860 - 5s/epoch - 20ms/step
# Epoch 246/300
# 247/247 - 5s - loss: 0.0463 - accuracy: 0.9856 - val_loss: 3.9771 - val_accuracy: 0.4547 - 5s/epoch - 20ms/step
# Epoch 247/300
# 247/247 - 5s - loss: 0.0082 - accuracy: 0.9979 - val_loss: 3.8361 - val_accuracy: 0.4866 - 5s/epoch - 20ms/step
# Epoch 248/300
# 247/247 - 5s - loss: 0.0025 - accuracy: 0.9991 - val_loss: 3.8199 - val_accuracy: 0.4916 - 5s/epoch - 20ms/step
# Epoch 249/300
# 247/247 - 5s - loss: 0.0021 - accuracy: 0.9992 - val_loss: 3.8213 - val_accuracy: 0.4966 - 5s/epoch - 20ms/step
# Epoch 250/300
# 247/247 - 5s - loss: 0.0014 - accuracy: 0.9992 - val_loss: 3.8467 - val_accuracy: 0.4969 - 5s/epoch - 20ms/step
# Epoch 251/300
# 247/247 - 5s - loss: 0.0013 - accuracy: 0.9993 - val_loss: 3.8466 - val_accuracy: 0.4985 - 5s/epoch - 20ms/step
# Epoch 252/300
# 247/247 - 5s - loss: 0.0012 - accuracy: 0.9994 - val_loss: 3.8586 - val_accuracy: 0.4975 - 5s/epoch - 20ms/step
# Epoch 253/300
# 247/247 - 5s - loss: 0.0012 - accuracy: 0.9993 - val_loss: 3.8525 - val_accuracy: 0.4988 - 5s/epoch - 20ms/step
# Epoch 254/300
# 247/247 - 5s - loss: 0.0011 - accuracy: 0.9993 - val_loss: 3.8612 - val_accuracy: 0.4999 - 5s/epoch - 20ms/step
# Epoch 255/300
# 247/247 - 5s - loss: 0.0011 - accuracy: 0.9993 - val_loss: 3.8718 - val_accuracy: 0.4990 - 5s/epoch - 20ms/step
# Epoch 256/300
# 247/247 - 5s - loss: 0.0011 - accuracy: 0.9994 - val_loss: 3.8651 - val_accuracy: 0.5016 - 5s/epoch - 20ms/step
# Epoch 257/300
# 247/247 - 5s - loss: 0.0010 - accuracy: 0.9993 - val_loss: 3.8630 - val_accuracy: 0.5013 - 5s/epoch - 20ms/step
# Epoch 258/300
# 247/247 - 5s - loss: 0.0010 - accuracy: 0.9992 - val_loss: 3.8882 - val_accuracy: 0.5025 - 5s/epoch - 20ms/step
# Epoch 259/300
# 247/247 - 5s - loss: 9.8136e-04 - accuracy: 0.9993 - val_loss: 3.8915 - val_accuracy: 0.5016 - 5s/epoch - 20ms/step
# Epoch 260/300
# 247/247 - 5s - loss: 9.7281e-04 - accuracy: 0.9993 - val_loss: 3.8996 - val_accuracy: 0.5020 - 5s/epoch - 20ms/step
# Epoch 261/300
# 247/247 - 5s - loss: 9.8214e-04 - accuracy: 0.9992 - val_loss: 3.9112 - val_accuracy: 0.5023 - 5s/epoch - 20ms/step
# Epoch 262/300
# 247/247 - 5s - loss: 0.0272 - accuracy: 0.9927 - val_loss: 5.3413 - val_accuracy: 0.3218 - 5s/epoch - 20ms/step
# Epoch 263/300
# 247/247 - 5s - loss: 0.1470 - accuracy: 0.9529 - val_loss: 4.4691 - val_accuracy: 0.4332 - 5s/epoch - 20ms/step
# Epoch 264/300
# 247/247 - 5s - loss: 0.0135 - accuracy: 0.9961 - val_loss: 3.8874 - val_accuracy: 0.4772 - 5s/epoch - 20ms/step
# Epoch 265/300
# 247/247 - 5s - loss: 0.0031 - accuracy: 0.9993 - val_loss: 3.8692 - val_accuracy: 0.4927 - 5s/epoch - 20ms/step
# Epoch 266/300
# 247/247 - 5s - loss: 0.0016 - accuracy: 0.9993 - val_loss: 3.8338 - val_accuracy: 0.4941 - 5s/epoch - 20ms/step
# Epoch 267/300
# 247/247 - 5s - loss: 0.0014 - accuracy: 0.9993 - val_loss: 3.8308 - val_accuracy: 0.4951 - 5s/epoch - 20ms/step
# Epoch 268/300
# 247/247 - 5s - loss: 0.0013 - accuracy: 0.9994 - val_loss: 3.8276 - val_accuracy: 0.4965 - 5s/epoch - 20ms/step
# Epoch 269/300
# 247/247 - 5s - loss: 0.0012 - accuracy: 0.9992 - val_loss: 3.8411 - val_accuracy: 0.4945 - 5s/epoch - 20ms/step
# Epoch 270/300
# 247/247 - 5s - loss: 0.0011 - accuracy: 0.9994 - val_loss: 3.8576 - val_accuracy: 0.4960 - 5s/epoch - 20ms/step
# Epoch 271/300
# 247/247 - 5s - loss: 0.0011 - accuracy: 0.9992 - val_loss: 3.8370 - val_accuracy: 0.4959 - 5s/epoch - 20ms/step
# Epoch 272/300
# 247/247 - 5s - loss: 0.0010 - accuracy: 0.9993 - val_loss: 3.8538 - val_accuracy: 0.4950 - 5s/epoch - 20ms/step
# Epoch 273/300
# 247/247 - 5s - loss: 0.0010 - accuracy: 0.9992 - val_loss: 3.8659 - val_accuracy: 0.4965 - 5s/epoch - 20ms/step
# Epoch 274/300
# 247/247 - 5s - loss: 9.9622e-04 - accuracy: 0.9993 - val_loss: 3.8866 - val_accuracy: 0.4969 - 5s/epoch - 20ms/step
# Epoch 275/300
# 247/247 - 5s - loss: 9.9199e-04 - accuracy: 0.9993 - val_loss: 3.8784 - val_accuracy: 0.4968 - 5s/epoch - 20ms/step
# Epoch 276/300
# 247/247 - 5s - loss: 9.6879e-04 - accuracy: 0.9993 - val_loss: 3.8974 - val_accuracy: 0.4997 - 5s/epoch - 20ms/step
# Epoch 277/300
# 247/247 - 5s - loss: 9.6394e-04 - accuracy: 0.9991 - val_loss: 3.9024 - val_accuracy: 0.4992 - 5s/epoch - 20ms/step
# Epoch 278/300
# 247/247 - 5s - loss: 9.6612e-04 - accuracy: 0.9993 - val_loss: 3.9148 - val_accuracy: 0.4983 - 5s/epoch - 20ms/step
# Epoch 279/300
# 247/247 - 5s - loss: 9.3980e-04 - accuracy: 0.9993 - val_loss: 3.9396 - val_accuracy: 0.4978 - 5s/epoch - 20ms/step
# Epoch 280/300
# 247/247 - 5s - loss: 9.3482e-04 - accuracy: 0.9991 - val_loss: 3.8880 - val_accuracy: 0.4968 - 5s/epoch - 20ms/step
# Epoch 281/300
# 247/247 - 5s - loss: 9.5371e-04 - accuracy: 0.9993 - val_loss: 4.0046 - val_accuracy: 0.4989 - 5s/epoch - 20ms/step
# Epoch 282/300
# 247/247 - 5s - loss: 9.3143e-04 - accuracy: 0.9993 - val_loss: 3.8732 - val_accuracy: 0.4992 - 5s/epoch - 20ms/step
# Epoch 283/300
# 247/247 - 5s - loss: 9.9039e-04 - accuracy: 0.9994 - val_loss: 4.0879 - val_accuracy: 0.4937 - 5s/epoch - 20ms/step
# Epoch 284/300
# 247/247 - 5s - loss: 0.0010 - accuracy: 0.9991 - val_loss: 3.8987 - val_accuracy: 0.5017 - 5s/epoch - 20ms/step
# Epoch 285/300
# 247/247 - 5s - loss: 0.0011 - accuracy: 0.9993 - val_loss: 3.9295 - val_accuracy: 0.4993 - 5s/epoch - 20ms/step
# Epoch 286/300
# 247/247 - 5s - loss: 0.1145 - accuracy: 0.9671 - val_loss: 4.7654 - val_accuracy: 0.3825 - 5s/epoch - 20ms/step
# Epoch 287/300
# 247/247 - 5s - loss: 0.0520 - accuracy: 0.9841 - val_loss: 3.9028 - val_accuracy: 0.4672 - 5s/epoch - 20ms/step
# Epoch 288/300
# 247/247 - 5s - loss: 0.0077 - accuracy: 0.9981 - val_loss: 3.9210 - val_accuracy: 0.4819 - 5s/epoch - 20ms/step
# Epoch 289/300
# 247/247 - 5s - loss: 0.0034 - accuracy: 0.9990 - val_loss: 3.9534 - val_accuracy: 0.4894 - 5s/epoch - 20ms/step
# Epoch 290/300
# 247/247 - 5s - loss: 0.0016 - accuracy: 0.9994 - val_loss: 3.9338 - val_accuracy: 0.4900 - 5s/epoch - 20ms/step
# Epoch 291/300
# 247/247 - 5s - loss: 0.0013 - accuracy: 0.9993 - val_loss: 3.9391 - val_accuracy: 0.4911 - 5s/epoch - 20ms/step
# Epoch 292/300
# 247/247 - 5s - loss: 0.0012 - accuracy: 0.9993 - val_loss: 3.9413 - val_accuracy: 0.4913 - 5s/epoch - 20ms/step
# Epoch 293/300
# 247/247 - 5s - loss: 0.0011 - accuracy: 0.9992 - val_loss: 3.9534 - val_accuracy: 0.4922 - 5s/epoch - 20ms/step
# Epoch 294/300
# 247/247 - 5s - loss: 0.0011 - accuracy: 0.9993 - val_loss: 3.9570 - val_accuracy: 0.4923 - 5s/epoch - 20ms/step
# Epoch 295/300
# 247/247 - 5s - loss: 0.0010 - accuracy: 0.9995 - val_loss: 3.9536 - val_accuracy: 0.4931 - 5s/epoch - 20ms/step
# Epoch 296/300
# 247/247 - 5s - loss: 0.0010 - accuracy: 0.9992 - val_loss: 3.9610 - val_accuracy: 0.4932 - 5s/epoch - 20ms/step
# Epoch 297/300
# 247/247 - 5s - loss: 0.0010 - accuracy: 0.9993 - val_loss: 3.9559 - val_accuracy: 0.4937 - 5s/epoch - 20ms/step
# Epoch 298/300
# 247/247 - 5s - loss: 9.8012e-04 - accuracy: 0.9994 - val_loss: 4.0053 - val_accuracy: 0.4944 - 5s/epoch - 20ms/step
# Epoch 299/300
# 247/247 - 5s - loss: 9.2791e-04 - accuracy: 0.9994 - val_loss: 3.9794 - val_accuracy: 0.4942 - 5s/epoch - 20ms/step
# Epoch 300/300
# 247/247 - 5s - loss: 9.4194e-04 - accuracy: 0.9993 - val_loss: 4.0133 - val_accuracy: 0.4954 - 5s/epoch - 20ms/step

# %%
accuracies = model_train_info.history['accuracy']
val_accuracies = model_train_info.history['val_accuracy']

plt.plot(list(range(epochs)), accuracies, label = 'accuracy')
plt.plot(list(range(epochs)), val_accuracies, label = 'val_accuracy')
plt.legend()
plt.grid()
plt.xticks(ticks = list(range(1, epochs + 1))) 
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.xticks(ticks=list(range(0, epochs + 1, 50)))
plt.show()

# %% [markdown]
# 準確度

# %%
print(f"資料: {mfcc_list_scaled.shape}")
print(f"最高準確率: {max(val_accuracies)}")
# Out:
# 資料: (39423, 13, 44)
# 最高準確率: 0.5048826932907104

# %%
model.save(f"{os.getcwd()}\\cnn_model.h5")
